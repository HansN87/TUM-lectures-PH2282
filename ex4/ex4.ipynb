# %%
'''
Statistical and Machine Learning Methods in Particle and Astrophysics
TUM - summer term 2019
M. Agostini <matteo.agostini@tum.de> and Hans Niederhausen@tum.de <hans.niederhausen@tum.de>

Ex 4, "A realistic maximum likelihood analysis: 
        The discovery of a diffuse flux of high-energy astrophysical neutrinos by IceCube"

    learning goals: perform a maximum likelihood analysis with binned observations
    1) build a (complex) statistical model from events generated with Monte Carlo techniques
    2) generate data (counts) from the model prediction
    3) extract estimated (MLE) model parameters from the generated data
    4) perform hypothesis test (MLR): H0: bkg only - against - H1: bkg + signal 
        4a) calculate observed test-statistic value
        4b) repeat steps 2-3-4 and build probability distribution of the test statistic for the bkg only case
        4c) calculate p-value (evidence against bkg only case)
       
the example is motivated by the following papers: 
Phys. Rev. Lett. 113, 101101 (2014)
Phys. Rev. D 91, 022001 (2015)
'''

# %%
from analyze_data import diffuse_analysis
import numpy as np
import matplotlib.pyplot as plt

# need to import mc event generator
from generate_mcevents import generate_pseudoMC

# number of mc events to be generated (or loaded)
nevents = 1.e4

# the line below will generate the MC events and write them to disk
# this needs to be done only once.
# if the MC events have already been generated in a previous step
# simply comment out the line below.
#outfiles = generate_pseudoMC(nevents)

# insted, if the MC events already exist on disk
# simply uncomment the line below
# and no events will be newly generated but the location of the MC events on disk will be returned
outfiles = generate_pseudoMC(nevents, precomputed=True)

# %%
# read MC events from disk
# prepare functions to calculate the model prediction for the poisson means in each analysis bin 
# (expected counts)
ana = diffuse_analysis(outfiles, seed=0)

# for now assume 3 years of detector operation
ana.set_ltime(3)

# set 5 bins per decade from 100 GeV to 10 PeV in reconstructed energy (our observable)
edges = np.linspace(2.0, 7.0, 26) 
centers = 0.5*(edges[1:]+edges[:-1])

# in what follows we distinguish between nominal parameters ("nominal MC") and the parameters
# realized in our hypothetical universe ("true MC").
# nominal MC corresponds to the parameter values that are assumed plausible before our experiment is carried out.
# (i.e. either from previous measurements or theory considerations)

# define nominal MC values
conv_norm = 1.0
astro_norm = 1.0
astro_gamma = 2.0
pars_mc = [conv_norm, astro_norm, astro_gamma]

# generate the model prediction in each analysis bin from MC for "nominal values"
mus_sum = ana.get_expectations(edges, pars_mc) # S+B
mus_conv = ana.get_expectations_conv(edges, conv_norm) # B
mus_astro = ana.get_expectations_astro(edges, [astro_norm, astro_gamma]) # S

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))

# we will visualize the nominal bkg expectation first
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_conv, histtype='step', color='blue', linewidth=1, zorder=10, label='nominal MC (B)')

# in a real life experiment the nominal assumption never fits the data exactly.
# we therefore generate pseudo-data from a slightly different set of parameter values ("true MC")
# these parameter values are the "true" values realized by nature in our hypothetical universe

conv_norm = 1.1
astro_norm = 1.0
astro_gamma = 2.3
pars_nature = [conv_norm, astro_norm, astro_gamma]

# generate the model prediction in each analysis bin from MC for "true values"
mus_nature = ana.get_expectations(edges, pars_nature)

# generate poisson random variables from model prediction
pseudo_data = ana.generate_pseudo_data(mus_nature)

# visualize "observed" data
pseudo_data_err_low, pseudo_data_err_up = ana.get_poisson_confidence_intervals(pseudo_data)
ax.errorbar(centers, pseudo_data,yerr=[pseudo_data_err_low, pseudo_data_err_up], label='$data$', markersize = 6.0, color='black', fmt='o', zorder=20, elinewidth=2)

ax.set_yscale('log')
ax.set_ylim([1.e-1, 100])

ax.set_xlabel('log10(rec_energy / GeV)', fontsize=20)
ax.set_ylabel('counts', fontsize=20)
for axis in ['top','bottom','left','right']:
          ax.spines[axis].set_linewidth(1.5)
          ax.spines[axis].set_color('0.0')
    
ax.tick_params(axis='both', which='both', width=1.5, colors='0.0', labelsize=20)
ax.yaxis.set_ticks_position('both')

plt.legend(bbox_to_anchor=[0.99, 0.99], loc='upper right', prop={'size':13}, ncol=1, fancybox=True)

plt.show()

# %%
# same plot as before
# but we also add the nominal signal prediction (red)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))

contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_sum, histtype='step', color='gray', linewidth=2, zorder=10, label='nominal MC (sum)')
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_conv, histtype='step', color='blue', linewidth=1, zorder=10, label='nominal MC (B)')
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_astro, histtype='step', color='red', linewidth=1, zorder=10, label='nominal MC (S)')

ax.errorbar(centers, pseudo_data,yerr=[pseudo_data_err_low, pseudo_data_err_up], label='$data$', markersize = 6.0, color='black', fmt='o', zorder=20, elinewidth=2)

ax.set_yscale('log')
ax.set_ylim([1.e-1, 100])

ax.set_xlabel('log10(rec_energy / GeV)', fontsize=20)
ax.set_ylabel('counts', fontsize=20)
for axis in ['top','bottom','left','right']:
          ax.spines[axis].set_linewidth(1.5)
          ax.spines[axis].set_color('0.0')
    
ax.tick_params(axis='both', which='both', width=1.5, colors='0.0', labelsize=20)
ax.yaxis.set_ticks_position('both')

plt.legend(bbox_to_anchor=[0.99, 0.99], loc='upper right', prop={'size':13}, ncol=1, fancybox=True)

plt.show()

# note: the MC and the data do not match exactly because the correspond to different sets
# of parameter values.
# However the nominal parameter values will provide a reasonable seed for the numerical likelihood optimization
# we will do later on.

# %%
# now replace the nominal MC expectations
# with the true MC expectations

# this compares the realized data observations to the true model that generated the data

# generate the model prediction in each analysis bin from MC for "true values"
mus_nature = ana.get_expectations(edges, pars_nature)
mus_conv_nature = ana.get_expectations_conv(edges, pars_nature[0])
mus_astro_nature = ana.get_expectations_astro(edges, pars_nature[1:])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))

contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_nature, histtype='step', color='gray', linewidth=2, zorder=10, label='true MC (sum)') 
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_conv_nature, histtype='step', color='blue', linewidth=1, zorder=10, label='true MC (B)') 
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_astro_nature, histtype='step', color='red', linewidth=1, zorder=10, label='true MC (S)')

ax.errorbar(centers, pseudo_data,yerr=[pseudo_data_err_low, pseudo_data_err_up], label='data', markersize = 6.0, color='black', fmt='o', zorder=20, elinewidth=2)

ax.set_yscale('log')
ax.set_ylim([1.e-1, 100])

ax.set_xlabel('log10(rec_energy / GeV)', fontsize=20)
ax.set_ylabel('counts', fontsize=20)
for axis in ['top','bottom','left','right']: 
    ax.spines[axis].set_linewidth(1.5)
    ax.spines[axis].set_color('0.0')

ax.tick_params(axis='both', which='both', width=1.5, colors='0.0', labelsize=20)
ax.yaxis.set_ticks_position('both')

plt.legend(bbox_to_anchor=[0.99, 0.99], loc='upper right', prop={'size':13}, ncol=1, fancybox=True)

plt.show()

# obviously the data is described better by the true set of parameter values
# note the large statistical fluctuations in the signal region (high energy)
# where each bin contains only a few events

# %%
# Let us start with the background only fit
# the background only fit has only one free parameter: the normalization of the background component
# (related to the intensity of the flux of conventional atmospheric neutrinos)

conv_norm_seed = pars_mc[0]
restricted_pars_seed = [conv_norm_seed]

# since we are interested in the background-only scenario
# we need to fix the signal expectation to 0 
astro_norm_H0 = 0.0
astro_index_H0 = 12.0 # undefined for norm=0.0, could be any value.

pars_H0 = [astro_norm_H0, astro_norm_H0] 

# get the estimated background normalization from the background fit
pars_fit, neg_logllh_fit = ana.get_restricted_fit(bins, pseudo_data, restricted_pars_seed,  pars_H0)

# visualize the fit result and compare to data
# store the values corresponding to the best-background-fit values
pars_H0 = [pars_fit[0]]+pars_H0
print pars_H0

# generate the model prediction in each analysis bin from MC for the bkg-only fit parameters
mus = ana.get_expectations(edges, pars_H0)
mus_conv = ana.get_expectations_conv(edges, pars_H0[0])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus, histtype='step', color='gray', linewidth=2, zorder=10, label='bg-fit MC (sum)')
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_conv, histtype='step', color='blue', linewidth=1, zorder=10, label='bg-fit MC (B)')
ax.errorbar(centers, pseudo_data,yerr=[pseudo_data_err_low, pseudo_data_err_up], label='data', markersize = 6.0, color='black', fmt='o', zorder=20, elinewidth=2)

ax.set_yscale('log')
ax.set_ylim([1.e-1, 100])
ax.set_xlabel('log10(rec_energy / GeV)', fontsize=20)
ax.set_ylabel('counts', fontsize=20)
for axis in ['top','bottom','left','right']: 
    ax.spines[axis].set_linewidth(1.5)
    ax.spines[axis].set_color('0.0')

ax.tick_params(axis='both', which='both', width=1.5, colors='0.0', labelsize=20)
ax.yaxis.set_ticks_position('both')

plt.legend(bbox_to_anchor=[0.99, 0.99], loc='upper right', prop={'size':13}, ncol=1, fancybox=True)

plt.show()

# the data is described well by the model in the background region (low energies)
# however there exists a tail of several events at highest energies that is not captured by the background model.
# does this provide sufficient evidence against the background only case?
# in other words - does this data require a second component (the astrophysical neutrino signal)?
# Out:
# [1.292315434031253, 0.0, 0.0]

# %%
# We repeat the fit but now include the signal parameters
pars_fit, neg_logllh_fit = ana.get_full_fit(bins, pseudo_data, pars_mc)

# generate the model prediction in each analysis bin from MC for the best-fit parameters
mus = ana.get_expectations(edges, pars_fit)
mus_conv = ana.get_expectations_conv(edges, pars_fit[0])
mus_astro = ana.get_expectations_astro(edges, pars_fit[1:])

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus, histtype='step', color='gray', linewidth=2, zorder=10, label='bestfit MC (sum)')
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_conv, histtype='step', color='blue', linewidth=1, zorder=10, label='bestfit MC (B)')
contents, bins, _ = plt.hist(centers, bins=edges, weights=mus_astro, histtype='step', color='red', linewidth=1, zorder=10, label='bestfit MC (S)')
ax.errorbar(centers, pseudo_data,yerr=[pseudo_data_err_low, pseudo_data_err_up], label='data', markersize = 6.0, color='black', fmt='o', zorder=20, elinewidth=2)

ax.set_yscale('log')
ax.set_ylim([1.e-1, 100])
ax.set_xlabel('log10(rec_energy / GeV)', fontsize=20)
ax.set_ylabel('counts', fontsize=20)
for axis in ['top','bottom','left','right']: 
    ax.spines[axis].set_linewidth(1.5)
    ax.spines[axis].set_color('0.0')

ax.tick_params(axis='both', which='both', width=1.5, colors='0.0', labelsize=20)
ax.yaxis.set_ticks_position('both')

plt.legend(bbox_to_anchor=[0.99, 0.99], loc='upper right', prop={'size':13}, ncol=1, fancybox=True)

plt.show()

# the best-fit prefers a non-zero signal contribution (astro_norm_fit = 0.45)
# the set of best-fit values does not exactly match the true parameters, 
# because of statistical variations in the data
# Out:
# [1.24639042 0.44626689 1.92766946]

# %%
# we calculate the test-statistic (likelihood ratio between hypotheses H0 (B) and H1 (S+B), see lecture for details)
results_obs = ana.get_test_statistic(bins, pseudo_data, pars_mc, [pars_H0[0]], pars_H0[1:])
best_fit_obs = results_obs[0]
bg_only_fit = results_obs[1]
ts_obs = results_obs[2]

# the observed TS value is 23.2

print "the observed best fit (full model) is conv_norm=", best_fit_obs[0], "astro_norm=", best_fit_obs[1], "astro_gamma=", best_fit_obs[2]
print "the observed background only fit is conv_norm=", bg_only_fit[0], "(with astro_norm=0.0 const. and astro_gamma undefined)"
print "the observed TS value is -2 log Lambda=", ts_obs

# in order to interpret the meaning of this value, we need to know the distribution of the TS assuming
# that the background-only hypothesis is true

# this distribution is in general unknown. but can be estimated by Monte Carlo (toy experiments)
# we generate  samples from the TS distribution assuming the best-background-fit values are true
# (beware of possible dependencies on nuisance parameters in complicated problems!)

# this is done by repeatedly generating new datasets from best background-only hypothesis
# and then fitting these artificial datasets with both hypothesis (B and S+B).
# i.e. for each dataset we calculate and store the corresponding TS value (one sample)
results_pseudo_data = ana.get_distributions_from_pseudo_data(bins, pars_mc, [pars_H0[0]], pars_H0[1:], pars_H0, 10000)

# unfortunately this is a time-consuming process
# Out:
# the observed best fit (full model) is conv_norm= 1.24639042074718 astro_norm= 0.4462668927377353 astro_gamma= 1.9276694583096934
# the observed background only fit is conv_norm= 1.29231543381 (with astro_norm=0.0 const. and astro_gamma undefined)
# the observed TS value is -2 log Lambda= 23.187980630000766
# analyzed 0 / 10000 datasets.
# analyzed 10 / 10000 datasets.
# analyzed 20 / 10000 datasets.
# analyzed 30 / 10000 datasets.
# analyzed 40 / 10000 datasets.
# analyzed 50 / 10000 datasets.
# analyzed 60 / 10000 datasets.
# analyzed 70 / 10000 datasets.
# analyzed 80 / 10000 datasets.
# analyzed 90 / 10000 datasets.
# analyzed 100 / 10000 datasets.
# analyzed 110 / 10000 datasets.
# analyzed 120 / 10000 datasets.
# analyzed 130 / 10000 datasets.
# analyzed 140 / 10000 datasets.
# analyzed 150 / 10000 datasets.
# analyzed 160 / 10000 datasets.
# analyzed 170 / 10000 datasets.
# analyzed 180 / 10000 datasets.
# analyzed 190 / 10000 datasets.
# analyzed 200 / 10000 datasets.
# analyzed 210 / 10000 datasets.
# analyzed 220 / 10000 datasets.
# analyzed 230 / 10000 datasets.
# analyzed 240 / 10000 datasets.
# analyzed 250 / 10000 datasets.
# analyzed 260 / 10000 datasets.
# analyzed 270 / 10000 datasets.
# analyzed 280 / 10000 datasets.
# analyzed 290 / 10000 datasets.
# analyzed 300 / 10000 datasets.
# analyzed 310 / 10000 datasets.
# analyzed 320 / 10000 datasets.
# analyzed 330 / 10000 datasets.
# analyzed 340 / 10000 datasets.
# analyzed 350 / 10000 datasets.
# analyzed 360 / 10000 datasets.
# analyzed 370 / 10000 datasets.
# analyzed 380 / 10000 datasets.
# analyzed 390 / 10000 datasets.
# analyzed 400 / 10000 datasets.
# analyzed 410 / 10000 datasets.
# analyzed 420 / 10000 datasets.
# analyzed 430 / 10000 datasets.
# analyzed 440 / 10000 datasets.
# analyzed 450 / 10000 datasets.
# analyzed 460 / 10000 datasets.
# analyzed 470 / 10000 datasets.
# analyzed 480 / 10000 datasets.
# analyzed 490 / 10000 datasets.
# analyzed 500 / 10000 datasets.
# analyzed 510 / 10000 datasets.
# analyzed 520 / 10000 datasets.
# analyzed 530 / 10000 datasets.
# analyzed 540 / 10000 datasets.
# analyzed 550 / 10000 datasets.
# analyzed 560 / 10000 datasets.
# analyzed 570 / 10000 datasets.
# analyzed 580 / 10000 datasets.
# analyzed 590 / 10000 datasets.
# analyzed 600 / 10000 datasets.
# analyzed 610 / 10000 datasets.
# analyzed 620 / 10000 datasets.
# analyzed 630 / 10000 datasets.
# analyzed 640 / 10000 datasets.
# analyzed 650 / 10000 datasets.
# analyzed 660 / 10000 datasets.
# analyzed 670 / 10000 datasets.
# analyzed 680 / 10000 datasets.
# analyzed 690 / 10000 datasets.
# analyzed 700 / 10000 datasets.
# analyzed 710 / 10000 datasets.
# analyzed 720 / 10000 datasets.
# analyzed 730 / 10000 datasets.
# analyzed 740 / 10000 datasets.
# analyzed 750 / 10000 datasets.
# analyzed 760 / 10000 datasets.
# analyzed 770 / 10000 datasets.
# analyzed 780 / 10000 datasets.
# analyzed 790 / 10000 datasets.
# analyzed 800 / 10000 datasets.
# analyzed 810 / 10000 datasets.
# analyzed 820 / 10000 datasets.
# analyze_data_v2.py:52: RuntimeWarning: overflow encountered in power
# analyze_data_v2.py:58: RuntimeWarning: invalid value encountered in multiply
# analyze_data_v2.py:76: RuntimeWarning: invalid value encountered in less
# /home/hans/.local/lib/python2.7/site-packages/numpy/lib/function_base.py:1273: RuntimeWarning: invalid value encountered in subtract
#   a = op(a[slice1], a[slice2])
# analyzed 830 / 10000 datasets.
# analyzed 840 / 10000 datasets.
# analyzed 850 / 10000 datasets.
# analyzed 860 / 10000 datasets.
# analyzed 870 / 10000 datasets.
# analyzed 880 / 10000 datasets.
# analyzed 890 / 10000 datasets.
# analyzed 900 / 10000 datasets.
# analyzed 910 / 10000 datasets.
# analyzed 920 / 10000 datasets.
# analyzed 930 / 10000 datasets.
# analyzed 940 / 10000 datasets.
# analyzed 950 / 10000 datasets.
# analyzed 960 / 10000 datasets.
# analyzed 970 / 10000 datasets.
# analyzed 980 / 10000 datasets.
# analyzed 990 / 10000 datasets.
# analyzed 1000 / 10000 datasets.
# analyzed 1010 / 10000 datasets.
# analyzed 1020 / 10000 datasets.
# analyzed 1030 / 10000 datasets.
# analyzed 1040 / 10000 datasets.
# analyzed 1050 / 10000 datasets.
# analyzed 1060 / 10000 datasets.
# analyzed 1070 / 10000 datasets.
# analyzed 1080 / 10000 datasets.
# analyzed 1090 / 10000 datasets.
# analyzed 1100 / 10000 datasets.
# analyzed 1110 / 10000 datasets.
# analyzed 1120 / 10000 datasets.
# analyzed 1130 / 10000 datasets.
# analyzed 1140 / 10000 datasets.
# analyzed 1150 / 10000 datasets.
# analyzed 1160 / 10000 datasets.
# analyzed 1170 / 10000 datasets.
# analyzed 1180 / 10000 datasets.
# analyzed 1190 / 10000 datasets.
# analyzed 1200 / 10000 datasets.
# analyzed 1210 / 10000 datasets.
# analyzed 1220 / 10000 datasets.
# analyzed 1230 / 10000 datasets.
# analyzed 1240 / 10000 datasets.
# analyzed 1250 / 10000 datasets.
# analyzed 1260 / 10000 datasets.
# analyzed 1270 / 10000 datasets.
# analyzed 1280 / 10000 datasets.
# analyzed 1290 / 10000 datasets.
# analyzed 1300 / 10000 datasets.
# analyzed 1310 / 10000 datasets.
# analyzed 1320 / 10000 datasets.
# analyzed 1330 / 10000 datasets.
# analyzed 1340 / 10000 datasets.
# analyzed 1350 / 10000 datasets.
# analyzed 1360 / 10000 datasets.
# analyzed 1370 / 10000 datasets.
# analyzed 1380 / 10000 datasets.
# analyzed 1390 / 10000 datasets.
# analyzed 1400 / 10000 datasets.
# analyzed 1410 / 10000 datasets.
# analyzed 1420 / 10000 datasets.
# analyzed 1430 / 10000 datasets.
# analyzed 1440 / 10000 datasets.
# analyzed 1450 / 10000 datasets.
# analyzed 1460 / 10000 datasets.
# analyzed 1470 / 10000 datasets.
# analyzed 1480 / 10000 datasets.
# analyzed 1490 / 10000 datasets.
# analyzed 1500 / 10000 datasets.
# analyzed 1510 / 10000 datasets.
# analyzed 1520 / 10000 datasets.
# analyzed 1530 / 10000 datasets.
# analyzed 1540 / 10000 datasets.
# analyzed 1550 / 10000 datasets.
# analyzed 1560 / 10000 datasets.
# analyzed 1570 / 10000 datasets.
# analyzed 1580 / 10000 datasets.
# analyzed 1590 / 10000 datasets.
# analyzed 1600 / 10000 datasets.
# analyzed 1610 / 10000 datasets.
# analyzed 1620 / 10000 datasets.
# analyzed 1630 / 10000 datasets.
# analyzed 1640 / 10000 datasets.
# analyzed 1650 / 10000 datasets.
# analyzed 1660 / 10000 datasets.
# analyzed 1670 / 10000 datasets.
# analyzed 1680 / 10000 datasets.
# analyzed 1690 / 10000 datasets.
# analyzed 1700 / 10000 datasets.
# analyzed 1710 / 10000 datasets.
# analyzed 1720 / 10000 datasets.
# analyzed 1730 / 10000 datasets.
# analyzed 1740 / 10000 datasets.
# analyzed 1750 / 10000 datasets.
# analyzed 1760 / 10000 datasets.
# analyzed 1770 / 10000 datasets.
# analyzed 1780 / 10000 datasets.
# analyzed 1790 / 10000 datasets.
# analyzed 1800 / 10000 datasets.
# analyzed 1810 / 10000 datasets.
# analyzed 1820 / 10000 datasets.
# analyzed 1830 / 10000 datasets.
# analyzed 1840 / 10000 datasets.
# analyzed 1850 / 10000 datasets.
# analyzed 1860 / 10000 datasets.
# analyzed 1870 / 10000 datasets.
# analyzed 1880 / 10000 datasets.
# analyzed 1890 / 10000 datasets.
# analyzed 1900 / 10000 datasets.
# analyzed 1910 / 10000 datasets.
# analyzed 1920 / 10000 datasets.
# analyzed 1930 / 10000 datasets.
# analyzed 1940 / 10000 datasets.
# analyzed 1950 / 10000 datasets.
# analyzed 1960 / 10000 datasets.
# analyzed 1970 / 10000 datasets.
# analyzed 1980 / 10000 datasets.
# analyzed 1990 / 10000 datasets.
# analyzed 2000 / 10000 datasets.
# analyzed 2010 / 10000 datasets.
# analyzed 2020 / 10000 datasets.
# analyzed 2030 / 10000 datasets.
# analyzed 2040 / 10000 datasets.
# analyzed 2050 / 10000 datasets.
# analyzed 2060 / 10000 datasets.
# analyzed 2070 / 10000 datasets.
# analyzed 2080 / 10000 datasets.
# analyzed 2090 / 10000 datasets.
# analyzed 2100 / 10000 datasets.
# analyzed 2110 / 10000 datasets.
# analyzed 2120 / 10000 datasets.
# analyzed 2130 / 10000 datasets.
# analyzed 2140 / 10000 datasets.
# analyzed 2150 / 10000 datasets.
# analyzed 2160 / 10000 datasets.
# analyzed 2170 / 10000 datasets.
# analyzed 2180 / 10000 datasets.
# analyzed 2190 / 10000 datasets.
# analyzed 2200 / 10000 datasets.
# analyzed 2210 / 10000 datasets.
# analyzed 2220 / 10000 datasets.
# analyzed 2230 / 10000 datasets.
# analyzed 2240 / 10000 datasets.
# analyzed 2250 / 10000 datasets.
# analyzed 2260 / 10000 datasets.
# analyzed 2270 / 10000 datasets.
# analyzed 2280 / 10000 datasets.
# analyzed 2290 / 10000 datasets.
# analyzed 2300 / 10000 datasets.
# analyzed 2310 / 10000 datasets.
# analyzed 2320 / 10000 datasets.
# analyzed 2330 / 10000 datasets.
# analyzed 2340 / 10000 datasets.
# analyzed 2350 / 10000 datasets.
# analyzed 2360 / 10000 datasets.
# analyzed 2370 / 10000 datasets.
# analyzed 2380 / 10000 datasets.
# analyzed 2390 / 10000 datasets.
# analyzed 2400 / 10000 datasets.
# analyzed 2410 / 10000 datasets.
# analyzed 2420 / 10000 datasets.
# analyzed 2430 / 10000 datasets.
# analyzed 2440 / 10000 datasets.
# analyzed 2450 / 10000 datasets.
# analyzed 2460 / 10000 datasets.
# analyzed 2470 / 10000 datasets.
# analyzed 2480 / 10000 datasets.
# analyzed 2490 / 10000 datasets.
# analyzed 2500 / 10000 datasets.
# analyzed 2510 / 10000 datasets.
# analyzed 2520 / 10000 datasets.
# analyzed 2530 / 10000 datasets.
# analyzed 2540 / 10000 datasets.
# analyzed 2550 / 10000 datasets.
# analyzed 2560 / 10000 datasets.
# analyzed 2570 / 10000 datasets.
# analyzed 2580 / 10000 datasets.
# analyzed 2590 / 10000 datasets.
# analyzed 2600 / 10000 datasets.
# analyzed 2610 / 10000 datasets.
# analyzed 2620 / 10000 datasets.
# analyzed 2630 / 10000 datasets.
# analyzed 2640 / 10000 datasets.
# analyzed 2650 / 10000 datasets.
# analyzed 2660 / 10000 datasets.
# analyzed 2670 / 10000 datasets.
# analyzed 2680 / 10000 datasets.
# analyzed 2690 / 10000 datasets.
# analyzed 2700 / 10000 datasets.
# analyzed 2710 / 10000 datasets.
# analyzed 2720 / 10000 datasets.
# analyzed 2730 / 10000 datasets.
# analyzed 2740 / 10000 datasets.
# analyzed 2750 / 10000 datasets.
# analyzed 2760 / 10000 datasets.
# analyzed 2770 / 10000 datasets.
# analyzed 2780 / 10000 datasets.
# analyzed 2790 / 10000 datasets.
# analyzed 2800 / 10000 datasets.
# analyzed 2810 / 10000 datasets.
# analyzed 2820 / 10000 datasets.
# analyzed 2830 / 10000 datasets.
# analyzed 2840 / 10000 datasets.
# analyzed 2850 / 10000 datasets.
# analyzed 2860 / 10000 datasets.
# analyzed 2870 / 10000 datasets.
# analyzed 2880 / 10000 datasets.
# analyzed 2890 / 10000 datasets.
# analyzed 2900 / 10000 datasets.
# analyzed 2910 / 10000 datasets.
# analyzed 2920 / 10000 datasets.
# analyzed 2930 / 10000 datasets.
# analyzed 2940 / 10000 datasets.
# analyzed 2950 / 10000 datasets.
# analyzed 2960 / 10000 datasets.
# analyzed 2970 / 10000 datasets.
# analyzed 2980 / 10000 datasets.
# analyzed 2990 / 10000 datasets.
# analyzed 3000 / 10000 datasets.
# analyzed 3010 / 10000 datasets.
# analyzed 3020 / 10000 datasets.
# analyzed 3030 / 10000 datasets.
# analyzed 3040 / 10000 datasets.
# analyzed 3050 / 10000 datasets.
# analyzed 3060 / 10000 datasets.
# analyzed 3070 / 10000 datasets.
# analyzed 3080 / 10000 datasets.
# analyzed 3090 / 10000 datasets.
# analyzed 3100 / 10000 datasets.
# analyzed 3110 / 10000 datasets.
# analyzed 3120 / 10000 datasets.
# analyzed 3130 / 10000 datasets.
# analyzed 3140 / 10000 datasets.
# analyzed 3150 / 10000 datasets.
# analyzed 3160 / 10000 datasets.
# analyzed 3170 / 10000 datasets.
# analyzed 3180 / 10000 datasets.
# analyzed 3190 / 10000 datasets.
# analyzed 3200 / 10000 datasets.
# analyzed 3210 / 10000 datasets.
# analyzed 3220 / 10000 datasets.
# analyzed 3230 / 10000 datasets.
# analyzed 3240 / 10000 datasets.
# analyzed 3250 / 10000 datasets.
# analyzed 3260 / 10000 datasets.
# analyzed 3270 / 10000 datasets.
# analyzed 3280 / 10000 datasets.
# analyzed 3290 / 10000 datasets.
# analyzed 3300 / 10000 datasets.
# analyzed 3310 / 10000 datasets.
# analyzed 3320 / 10000 datasets.
# analyzed 3330 / 10000 datasets.
# analyzed 3340 / 10000 datasets.
# analyzed 3350 / 10000 datasets.
# analyzed 3360 / 10000 datasets.
# analyzed 3370 / 10000 datasets.
# analyzed 3380 / 10000 datasets.
# analyzed 3390 / 10000 datasets.
# analyzed 3400 / 10000 datasets.
# analyzed 3410 / 10000 datasets.
# analyzed 3420 / 10000 datasets.
# analyzed 3430 / 10000 datasets.
# analyzed 3440 / 10000 datasets.
# analyzed 3450 / 10000 datasets.
# analyzed 3460 / 10000 datasets.
# analyzed 3470 / 10000 datasets.
# analyzed 3480 / 10000 datasets.
# analyzed 3490 / 10000 datasets.
# analyzed 3500 / 10000 datasets.
# analyzed 3510 / 10000 datasets.
# analyzed 3520 / 10000 datasets.
# analyzed 3530 / 10000 datasets.
# analyzed 3540 / 10000 datasets.
# analyzed 3550 / 10000 datasets.
# analyzed 3560 / 10000 datasets.
# analyzed 3570 / 10000 datasets.
# analyzed 3580 / 10000 datasets.
# analyzed 3590 / 10000 datasets.
# analyzed 3600 / 10000 datasets.
# analyzed 3610 / 10000 datasets.
# analyzed 3620 / 10000 datasets.
# analyzed 3630 / 10000 datasets.
# analyzed 3640 / 10000 datasets.
# analyzed 3650 / 10000 datasets.
# analyzed 3660 / 10000 datasets.
# analyzed 3670 / 10000 datasets.
# analyzed 3680 / 10000 datasets.
# analyzed 3690 / 10000 datasets.
# analyzed 3700 / 10000 datasets.
# analyzed 3710 / 10000 datasets.
# analyzed 3720 / 10000 datasets.
# analyzed 3730 / 10000 datasets.
# analyzed 3740 / 10000 datasets.
# analyzed 3750 / 10000 datasets.
# analyzed 3760 / 10000 datasets.
# analyzed 3770 / 10000 datasets.
# analyzed 3780 / 10000 datasets.
# analyzed 3790 / 10000 datasets.
# analyzed 3800 / 10000 datasets.
# analyzed 3810 / 10000 datasets.
# analyzed 3820 / 10000 datasets.
# analyzed 3830 / 10000 datasets.
# analyzed 3840 / 10000 datasets.
# analyzed 3850 / 10000 datasets.
# analyzed 3860 / 10000 datasets.
# analyzed 3870 / 10000 datasets.
# analyzed 3880 / 10000 datasets.
# analyzed 3890 / 10000 datasets.
# analyzed 3900 / 10000 datasets.
# analyzed 3910 / 10000 datasets.
# analyzed 3920 / 10000 datasets.
# analyzed 3930 / 10000 datasets.
# analyzed 3940 / 10000 datasets.
# analyzed 3950 / 10000 datasets.
# analyzed 3960 / 10000 datasets.
# analyzed 3970 / 10000 datasets.
# analyzed 3980 / 10000 datasets.
# analyzed 3990 / 10000 datasets.
# analyzed 4000 / 10000 datasets.
# analyzed 4010 / 10000 datasets.
# analyzed 4020 / 10000 datasets.
# analyzed 4030 / 10000 datasets.
# analyzed 4040 / 10000 datasets.
# analyzed 4050 / 10000 datasets.
# analyzed 4060 / 10000 datasets.
# analyzed 4070 / 10000 datasets.
# analyzed 4080 / 10000 datasets.
# analyzed 4090 / 10000 datasets.
# analyzed 4100 / 10000 datasets.
# analyzed 4110 / 10000 datasets.
# analyzed 4120 / 10000 datasets.
# analyzed 4130 / 10000 datasets.
# analyzed 4140 / 10000 datasets.
# analyzed 4150 / 10000 datasets.
# analyzed 4160 / 10000 datasets.
# analyzed 4170 / 10000 datasets.
# analyzed 4180 / 10000 datasets.
# analyzed 4190 / 10000 datasets.
# analyzed 4200 / 10000 datasets.
# analyzed 4210 / 10000 datasets.
# analyzed 4220 / 10000 datasets.
# analyzed 4230 / 10000 datasets.
# analyzed 4240 / 10000 datasets.
# analyzed 4250 / 10000 datasets.
# analyzed 4260 / 10000 datasets.
# analyzed 4270 / 10000 datasets.
# analyzed 4280 / 10000 datasets.
# analyzed 4290 / 10000 datasets.
# analyzed 4300 / 10000 datasets.
# analyzed 4310 / 10000 datasets.
# analyzed 4320 / 10000 datasets.
# analyzed 4330 / 10000 datasets.
# analyzed 4340 / 10000 datasets.
# analyzed 4350 / 10000 datasets.
# analyzed 4360 / 10000 datasets.
# analyzed 4370 / 10000 datasets.
# analyzed 4380 / 10000 datasets.
# analyzed 4390 / 10000 datasets.
# analyzed 4400 / 10000 datasets.
# analyzed 4410 / 10000 datasets.
# analyzed 4420 / 10000 datasets.
# analyzed 4430 / 10000 datasets.
# analyzed 4440 / 10000 datasets.
# analyzed 4450 / 10000 datasets.
# analyzed 4460 / 10000 datasets.
# analyzed 4470 / 10000 datasets.
# analyzed 4480 / 10000 datasets.
# analyzed 4490 / 10000 datasets.
# analyzed 4500 / 10000 datasets.
# analyzed 4510 / 10000 datasets.
# analyzed 4520 / 10000 datasets.
# analyzed 4530 / 10000 datasets.
# analyzed 4540 / 10000 datasets.
# analyzed 4550 / 10000 datasets.
# analyzed 4560 / 10000 datasets.
# analyzed 4570 / 10000 datasets.
# analyzed 4580 / 10000 datasets.
# analyzed 4590 / 10000 datasets.
# analyzed 4600 / 10000 datasets.
# analyzed 4610 / 10000 datasets.
# analyzed 4620 / 10000 datasets.
# analyzed 4630 / 10000 datasets.
# analyzed 4640 / 10000 datasets.
# analyzed 4650 / 10000 datasets.
# analyzed 4660 / 10000 datasets.
# analyzed 4670 / 10000 datasets.
# analyzed 4680 / 10000 datasets.
# analyzed 4690 / 10000 datasets.
# analyzed 4700 / 10000 datasets.
# analyzed 4710 / 10000 datasets.
# analyzed 4720 / 10000 datasets.
# analyzed 4730 / 10000 datasets.
# analyzed 4740 / 10000 datasets.
# analyzed 4750 / 10000 datasets.
# analyzed 4760 / 10000 datasets.
# analyzed 4770 / 10000 datasets.
# analyzed 4780 / 10000 datasets.
# analyzed 4790 / 10000 datasets.
# analyzed 4800 / 10000 datasets.
# analyzed 4810 / 10000 datasets.
# analyzed 4820 / 10000 datasets.
# analyzed 4830 / 10000 datasets.
# analyzed 4840 / 10000 datasets.
# analyzed 4850 / 10000 datasets.
# analyzed 4860 / 10000 datasets.
# analyzed 4870 / 10000 datasets.
# analyzed 4880 / 10000 datasets.
# analyzed 4890 / 10000 datasets.
# analyzed 4900 / 10000 datasets.
# analyzed 4910 / 10000 datasets.
# analyzed 4920 / 10000 datasets.
# analyzed 4930 / 10000 datasets.
# analyzed 4940 / 10000 datasets.
# analyzed 4950 / 10000 datasets.
# analyzed 4960 / 10000 datasets.
# analyzed 4970 / 10000 datasets.
# analyzed 4980 / 10000 datasets.
# analyzed 4990 / 10000 datasets.
# analyzed 5000 / 10000 datasets.
# analyzed 5010 / 10000 datasets.
# analyzed 5020 / 10000 datasets.
# analyzed 5030 / 10000 datasets.
# analyzed 5040 / 10000 datasets.
# analyzed 5050 / 10000 datasets.
# analyzed 5060 / 10000 datasets.
# analyzed 5070 / 10000 datasets.
# analyzed 5080 / 10000 datasets.
# analyzed 5090 / 10000 datasets.
# analyzed 5100 / 10000 datasets.
# analyzed 5110 / 10000 datasets.
# analyzed 5120 / 10000 datasets.
# analyzed 5130 / 10000 datasets.
# analyzed 5140 / 10000 datasets.
# analyzed 5150 / 10000 datasets.
# analyzed 5160 / 10000 datasets.
# analyzed 5170 / 10000 datasets.
# analyzed 5180 / 10000 datasets.
# analyzed 5190 / 10000 datasets.
# analyzed 5200 / 10000 datasets.
# analyzed 5210 / 10000 datasets.
# analyzed 5220 / 10000 datasets.
# analyzed 5230 / 10000 datasets.
# analyzed 5240 / 10000 datasets.
# analyzed 5250 / 10000 datasets.
# analyzed 5260 / 10000 datasets.
# analyzed 5270 / 10000 datasets.
# analyzed 5280 / 10000 datasets.
# analyzed 5290 / 10000 datasets.
# analyzed 5300 / 10000 datasets.
# analyzed 5310 / 10000 datasets.
# analyzed 5320 / 10000 datasets.
# analyzed 5330 / 10000 datasets.
# analyzed 5340 / 10000 datasets.
# analyzed 5350 / 10000 datasets.
# analyzed 5360 / 10000 datasets.
# analyzed 5370 / 10000 datasets.
# analyzed 5380 / 10000 datasets.
# analyzed 5390 / 10000 datasets.
# analyzed 5400 / 10000 datasets.
# analyzed 5410 / 10000 datasets.
# analyzed 5420 / 10000 datasets.
# analyzed 5430 / 10000 datasets.
# analyzed 5440 / 10000 datasets.
# analyzed 5450 / 10000 datasets.
# analyzed 5460 / 10000 datasets.
# analyzed 5470 / 10000 datasets.
# analyzed 5480 / 10000 datasets.
# analyzed 5490 / 10000 datasets.
# analyzed 5500 / 10000 datasets.
# analyzed 5510 / 10000 datasets.
# analyzed 5520 / 10000 datasets.
# analyzed 5530 / 10000 datasets.
# analyzed 5540 / 10000 datasets.
# analyzed 5550 / 10000 datasets.
# analyzed 5560 / 10000 datasets.
# analyzed 5570 / 10000 datasets.
# analyzed 5580 / 10000 datasets.
# analyzed 5590 / 10000 datasets.
# analyzed 5600 / 10000 datasets.
# analyzed 5610 / 10000 datasets.
# analyzed 5620 / 10000 datasets.
# analyzed 5630 / 10000 datasets.
# analyzed 5640 / 10000 datasets.
# analyzed 5650 / 10000 datasets.
# analyzed 5660 / 10000 datasets.
# analyzed 5670 / 10000 datasets.
# analyzed 5680 / 10000 datasets.
# analyzed 5690 / 10000 datasets.
# analyzed 5700 / 10000 datasets.
# analyzed 5710 / 10000 datasets.
# analyzed 5720 / 10000 datasets.
# analyzed 5730 / 10000 datasets.
# analyzed 5740 / 10000 datasets.
# analyzed 5750 / 10000 datasets.
# analyzed 5760 / 10000 datasets.
# analyzed 5770 / 10000 datasets.
# analyzed 5780 / 10000 datasets.
# analyzed 5790 / 10000 datasets.
# analyzed 5800 / 10000 datasets.
# analyzed 5810 / 10000 datasets.
# analyzed 5820 / 10000 datasets.
# analyzed 5830 / 10000 datasets.
# analyzed 5840 / 10000 datasets.
# analyzed 5850 / 10000 datasets.
# analyzed 5860 / 10000 datasets.
# analyzed 5870 / 10000 datasets.
# analyzed 5880 / 10000 datasets.
# analyzed 5890 / 10000 datasets.
# analyzed 5900 / 10000 datasets.
# analyzed 5910 / 10000 datasets.
# analyzed 5920 / 10000 datasets.
# analyzed 5930 / 10000 datasets.
# analyzed 5940 / 10000 datasets.
# analyzed 5950 / 10000 datasets.
# analyzed 5960 / 10000 datasets.
# analyzed 5970 / 10000 datasets.
# analyzed 5980 / 10000 datasets.
# analyzed 5990 / 10000 datasets.
# analyzed 6000 / 10000 datasets.
# analyzed 6010 / 10000 datasets.
# analyzed 6020 / 10000 datasets.
# analyzed 6030 / 10000 datasets.
# analyzed 6040 / 10000 datasets.
# analyzed 6050 / 10000 datasets.
# analyzed 6060 / 10000 datasets.
# analyzed 6070 / 10000 datasets.
# analyzed 6080 / 10000 datasets.
# analyzed 6090 / 10000 datasets.
# analyzed 6100 / 10000 datasets.
# analyzed 6110 / 10000 datasets.
# analyzed 6120 / 10000 datasets.
# analyzed 6130 / 10000 datasets.
# analyzed 6140 / 10000 datasets.
# analyzed 6150 / 10000 datasets.
# analyzed 6160 / 10000 datasets.
# analyzed 6170 / 10000 datasets.
# analyzed 6180 / 10000 datasets.
# analyzed 6190 / 10000 datasets.
# analyzed 6200 / 10000 datasets.
# analyzed 6210 / 10000 datasets.
# analyzed 6220 / 10000 datasets.
# analyzed 6230 / 10000 datasets.
# analyzed 6240 / 10000 datasets.
# analyzed 6250 / 10000 datasets.
# analyzed 6260 / 10000 datasets.
# analyzed 6270 / 10000 datasets.
# analyzed 6280 / 10000 datasets.
# analyzed 6290 / 10000 datasets.
# analyzed 6300 / 10000 datasets.
# analyzed 6310 / 10000 datasets.
# analyzed 6320 / 10000 datasets.
# analyzed 6330 / 10000 datasets.
# analyzed 6340 / 10000 datasets.
# analyzed 6350 / 10000 datasets.
# analyzed 6360 / 10000 datasets.
# analyzed 6370 / 10000 datasets.
# analyzed 6380 / 10000 datasets.
# analyzed 6390 / 10000 datasets.
# analyzed 6400 / 10000 datasets.
# analyzed 6410 / 10000 datasets.
# analyzed 6420 / 10000 datasets.
# analyzed 6430 / 10000 datasets.
# analyzed 6440 / 10000 datasets.
# analyzed 6450 / 10000 datasets.
# analyzed 6460 / 10000 datasets.
# analyzed 6470 / 10000 datasets.
# analyzed 6480 / 10000 datasets.
# analyzed 6490 / 10000 datasets.
# analyzed 6500 / 10000 datasets.
# analyzed 6510 / 10000 datasets.
# analyzed 6520 / 10000 datasets.
# analyzed 6530 / 10000 datasets.
# analyzed 6540 / 10000 datasets.
# analyzed 6550 / 10000 datasets.
# analyzed 6560 / 10000 datasets.
# analyzed 6570 / 10000 datasets.
# analyzed 6580 / 10000 datasets.
# analyzed 6590 / 10000 datasets.
# analyzed 6600 / 10000 datasets.
# analyzed 6610 / 10000 datasets.
# analyzed 6620 / 10000 datasets.
# analyzed 6630 / 10000 datasets.
# analyzed 6640 / 10000 datasets.
# analyzed 6650 / 10000 datasets.
# analyzed 6660 / 10000 datasets.
# analyzed 6670 / 10000 datasets.
# analyzed 6680 / 10000 datasets.
# analyzed 6690 / 10000 datasets.
# analyzed 6700 / 10000 datasets.
# analyzed 6710 / 10000 datasets.
# analyzed 6720 / 10000 datasets.
# analyzed 6730 / 10000 datasets.
# analyzed 6740 / 10000 datasets.
# analyzed 6750 / 10000 datasets.
# analyzed 6760 / 10000 datasets.
# analyzed 6770 / 10000 datasets.
# analyzed 6780 / 10000 datasets.
# analyzed 6790 / 10000 datasets.
# analyzed 6800 / 10000 datasets.
# analyzed 6810 / 10000 datasets.
# analyzed 6820 / 10000 datasets.
# analyzed 6830 / 10000 datasets.
# analyzed 6840 / 10000 datasets.
# analyzed 6850 / 10000 datasets.
# analyzed 6860 / 10000 datasets.
# analyzed 6870 / 10000 datasets.
# analyzed 6880 / 10000 datasets.
# analyzed 6890 / 10000 datasets.
# analyzed 6900 / 10000 datasets.
# analyzed 6910 / 10000 datasets.
# analyzed 6920 / 10000 datasets.
# analyzed 6930 / 10000 datasets.
# analyzed 6940 / 10000 datasets.
# analyzed 6950 / 10000 datasets.
# analyzed 6960 / 10000 datasets.
# analyzed 6970 / 10000 datasets.
# analyzed 6980 / 10000 datasets.
# analyzed 6990 / 10000 datasets.
# analyzed 7000 / 10000 datasets.
# analyzed 7010 / 10000 datasets.
# analyzed 7020 / 10000 datasets.
# analyzed 7030 / 10000 datasets.
# analyzed 7040 / 10000 datasets.
# analyzed 7050 / 10000 datasets.
# analyzed 7060 / 10000 datasets.
# analyzed 7070 / 10000 datasets.
# analyzed 7080 / 10000 datasets.
# analyzed 7090 / 10000 datasets.
# analyzed 7100 / 10000 datasets.
# analyzed 7110 / 10000 datasets.
# analyzed 7120 / 10000 datasets.
# analyzed 7130 / 10000 datasets.
# analyzed 7140 / 10000 datasets.
# analyzed 7150 / 10000 datasets.
# analyzed 7160 / 10000 datasets.
# analyzed 7170 / 10000 datasets.
# analyzed 7180 / 10000 datasets.
# analyzed 7190 / 10000 datasets.
# analyzed 7200 / 10000 datasets.
# analyzed 7210 / 10000 datasets.
# analyzed 7220 / 10000 datasets.
# analyzed 7230 / 10000 datasets.
# analyzed 7240 / 10000 datasets.
# analyzed 7250 / 10000 datasets.
# analyzed 7260 / 10000 datasets.
# analyzed 7270 / 10000 datasets.
# analyzed 7280 / 10000 datasets.
# analyzed 7290 / 10000 datasets.
# analyzed 7300 / 10000 datasets.
# analyzed 7310 / 10000 datasets.
# analyzed 7320 / 10000 datasets.
# analyzed 7330 / 10000 datasets.
# analyzed 7340 / 10000 datasets.
# analyzed 7350 / 10000 datasets.
# analyzed 7360 / 10000 datasets.
# analyzed 7370 / 10000 datasets.
# analyzed 7380 / 10000 datasets.
# analyzed 7390 / 10000 datasets.
# analyzed 7400 / 10000 datasets.
# analyzed 7410 / 10000 datasets.
# analyzed 7420 / 10000 datasets.
# analyzed 7430 / 10000 datasets.
# analyzed 7440 / 10000 datasets.
# analyzed 7450 / 10000 datasets.
# analyzed 7460 / 10000 datasets.
# analyzed 7470 / 10000 datasets.
# analyzed 7480 / 10000 datasets.
# analyzed 7490 / 10000 datasets.
# analyzed 7500 / 10000 datasets.
# analyzed 7510 / 10000 datasets.
# analyzed 7520 / 10000 datasets.
# analyzed 7530 / 10000 datasets.
# analyzed 7540 / 10000 datasets.
# analyzed 7550 / 10000 datasets.
# analyzed 7560 / 10000 datasets.
# analyzed 7570 / 10000 datasets.
# analyzed 7580 / 10000 datasets.
# analyzed 7590 / 10000 datasets.
# analyzed 7600 / 10000 datasets.
# analyzed 7610 / 10000 datasets.
# analyzed 7620 / 10000 datasets.
# analyzed 7630 / 10000 datasets.
# analyzed 7640 / 10000 datasets.
# analyzed 7650 / 10000 datasets.
# analyzed 7660 / 10000 datasets.
# analyzed 7670 / 10000 datasets.
# analyzed 7680 / 10000 datasets.
# analyzed 7690 / 10000 datasets.
# analyzed 7700 / 10000 datasets.
# analyzed 7710 / 10000 datasets.
# analyzed 7720 / 10000 datasets.
# analyzed 7730 / 10000 datasets.
# analyzed 7740 / 10000 datasets.
# analyzed 7750 / 10000 datasets.
# analyzed 7760 / 10000 datasets.
# analyzed 7770 / 10000 datasets.
# analyzed 7780 / 10000 datasets.
# analyzed 7790 / 10000 datasets.
# analyzed 7800 / 10000 datasets.
# analyzed 7810 / 10000 datasets.
# analyzed 7820 / 10000 datasets.
# analyzed 7830 / 10000 datasets.
# analyzed 7840 / 10000 datasets.
# analyzed 7850 / 10000 datasets.
# analyzed 7860 / 10000 datasets.
# analyzed 7870 / 10000 datasets.
# analyzed 7880 / 10000 datasets.
# analyzed 7890 / 10000 datasets.
# analyzed 7900 / 10000 datasets.
# analyzed 7910 / 10000 datasets.
# analyzed 7920 / 10000 datasets.
# analyzed 7930 / 10000 datasets.
# analyzed 7940 / 10000 datasets.
# analyzed 7950 / 10000 datasets.
# analyzed 7960 / 10000 datasets.
# analyzed 7970 / 10000 datasets.
# analyzed 7980 / 10000 datasets.
# analyzed 7990 / 10000 datasets.
# analyzed 8000 / 10000 datasets.
# analyzed 8010 / 10000 datasets.
# analyzed 8020 / 10000 datasets.
# analyzed 8030 / 10000 datasets.
# analyzed 8040 / 10000 datasets.
# analyzed 8050 / 10000 datasets.
# analyzed 8060 / 10000 datasets.
# analyzed 8070 / 10000 datasets.
# analyzed 8080 / 10000 datasets.
# analyzed 8090 / 10000 datasets.
# analyzed 8100 / 10000 datasets.
# analyzed 8110 / 10000 datasets.
# analyzed 8120 / 10000 datasets.
# analyzed 8130 / 10000 datasets.
# analyzed 8140 / 10000 datasets.
# analyzed 8150 / 10000 datasets.
# analyzed 8160 / 10000 datasets.
# analyzed 8170 / 10000 datasets.
# analyzed 8180 / 10000 datasets.
# analyzed 8190 / 10000 datasets.
# analyzed 8200 / 10000 datasets.
# analyzed 8210 / 10000 datasets.
# analyzed 8220 / 10000 datasets.
# analyzed 8230 / 10000 datasets.
# analyzed 8240 / 10000 datasets.
# analyzed 8250 / 10000 datasets.
# analyzed 8260 / 10000 datasets.
# analyzed 8270 / 10000 datasets.
# analyzed 8280 / 10000 datasets.
# analyzed 8290 / 10000 datasets.
# analyzed 8300 / 10000 datasets.
# analyzed 8310 / 10000 datasets.
# analyzed 8320 / 10000 datasets.
# analyzed 8330 / 10000 datasets.
# analyzed 8340 / 10000 datasets.
# analyzed 8350 / 10000 datasets.
# analyzed 8360 / 10000 datasets.
# analyzed 8370 / 10000 datasets.
# analyzed 8380 / 10000 datasets.
# analyzed 8390 / 10000 datasets.
# analyzed 8400 / 10000 datasets.
# analyzed 8410 / 10000 datasets.
# analyzed 8420 / 10000 datasets.
# analyzed 8430 / 10000 datasets.
# analyzed 8440 / 10000 datasets.
# analyzed 8450 / 10000 datasets.
# analyzed 8460 / 10000 datasets.
# analyzed 8470 / 10000 datasets.
# analyzed 8480 / 10000 datasets.
# analyzed 8490 / 10000 datasets.
# analyzed 8500 / 10000 datasets.
# analyzed 8510 / 10000 datasets.
# analyzed 8520 / 10000 datasets.
# analyzed 8530 / 10000 datasets.
# analyzed 8540 / 10000 datasets.
# analyzed 8550 / 10000 datasets.
# analyzed 8560 / 10000 datasets.
# analyzed 8570 / 10000 datasets.
# analyzed 8580 / 10000 datasets.
# analyzed 8590 / 10000 datasets.
# analyzed 8600 / 10000 datasets.
# analyzed 8610 / 10000 datasets.
# analyzed 8620 / 10000 datasets.
# analyzed 8630 / 10000 datasets.
# analyzed 8640 / 10000 datasets.
# analyzed 8650 / 10000 datasets.
# analyzed 8660 / 10000 datasets.
# analyzed 8670 / 10000 datasets.
# analyzed 8680 / 10000 datasets.
# analyzed 8690 / 10000 datasets.
# analyzed 8700 / 10000 datasets.
# analyzed 8710 / 10000 datasets.
# analyzed 8720 / 10000 datasets.
# analyzed 8730 / 10000 datasets.
# analyzed 8740 / 10000 datasets.
# analyzed 8750 / 10000 datasets.
# analyzed 8760 / 10000 datasets.
# analyzed 8770 / 10000 datasets.
# analyzed 8780 / 10000 datasets.
# analyzed 8790 / 10000 datasets.
# analyzed 8800 / 10000 datasets.
# analyzed 8810 / 10000 datasets.
# analyzed 8820 / 10000 datasets.
# analyzed 8830 / 10000 datasets.
# analyzed 8840 / 10000 datasets.
# analyzed 8850 / 10000 datasets.
# analyzed 8860 / 10000 datasets.
# analyzed 8870 / 10000 datasets.
# analyzed 8880 / 10000 datasets.
# analyzed 8890 / 10000 datasets.
# analyzed 8900 / 10000 datasets.
# analyzed 8910 / 10000 datasets.
# analyzed 8920 / 10000 datasets.
# analyzed 8930 / 10000 datasets.
# analyzed 8940 / 10000 datasets.
# analyzed 8950 / 10000 datasets.
# analyzed 8960 / 10000 datasets.
# analyzed 8970 / 10000 datasets.
# analyzed 8980 / 10000 datasets.
# analyzed 8990 / 10000 datasets.
# analyzed 9000 / 10000 datasets.
# analyzed 9010 / 10000 datasets.
# analyzed 9020 / 10000 datasets.
# analyzed 9030 / 10000 datasets.
# analyzed 9040 / 10000 datasets.
# analyzed 9050 / 10000 datasets.
# analyzed 9060 / 10000 datasets.
# analyzed 9070 / 10000 datasets.
# analyzed 9080 / 10000 datasets.
# analyzed 9090 / 10000 datasets.
# analyzed 9100 / 10000 datasets.
# analyzed 9110 / 10000 datasets.
# analyzed 9120 / 10000 datasets.
# analyzed 9130 / 10000 datasets.
# analyzed 9140 / 10000 datasets.
# analyzed 9150 / 10000 datasets.
# analyzed 9160 / 10000 datasets.
# analyzed 9170 / 10000 datasets.
# analyzed 9180 / 10000 datasets.
# analyzed 9190 / 10000 datasets.
# analyzed 9200 / 10000 datasets.
# analyzed 9210 / 10000 datasets.
# analyzed 9220 / 10000 datasets.
# analyzed 9230 / 10000 datasets.
# analyzed 9240 / 10000 datasets.
# analyzed 9250 / 10000 datasets.
# analyzed 9260 / 10000 datasets.
# analyzed 9270 / 10000 datasets.
# analyzed 9280 / 10000 datasets.
# analyzed 9290 / 10000 datasets.
# analyzed 9300 / 10000 datasets.
# analyzed 9310 / 10000 datasets.
# analyzed 9320 / 10000 datasets.
# analyzed 9330 / 10000 datasets.
# analyzed 9340 / 10000 datasets.
# analyzed 9350 / 10000 datasets.
# analyzed 9360 / 10000 datasets.
# analyzed 9370 / 10000 datasets.
# analyzed 9380 / 10000 datasets.
# analyzed 9390 / 10000 datasets.
# analyzed 9400 / 10000 datasets.
# analyzed 9410 / 10000 datasets.
# analyzed 9420 / 10000 datasets.
# analyzed 9430 / 10000 datasets.
# analyzed 9440 / 10000 datasets.
# analyzed 9450 / 10000 datasets.
# analyzed 9460 / 10000 datasets.
# analyzed 9470 / 10000 datasets.
# analyzed 9480 / 10000 datasets.
# analyzed 9490 / 10000 datasets.
# analyzed 9500 / 10000 datasets.
# analyzed 9510 / 10000 datasets.
# analyzed 9520 / 10000 datasets.
# analyzed 9530 / 10000 datasets.
# analyzed 9540 / 10000 datasets.
# analyzed 9550 / 10000 datasets.
# analyzed 9560 / 10000 datasets.
# analyzed 9570 / 10000 datasets.
# analyzed 9580 / 10000 datasets.
# analyzed 9590 / 10000 datasets.
# analyzed 9600 / 10000 datasets.
# analyzed 9610 / 10000 datasets.
# analyzed 9620 / 10000 datasets.
# analyzed 9630 / 10000 datasets.
# analyzed 9640 / 10000 datasets.
# analyzed 9650 / 10000 datasets.
# analyzed 9660 / 10000 datasets.
# analyzed 9670 / 10000 datasets.
# analyzed 9680 / 10000 datasets.
# analyzed 9690 / 10000 datasets.
# analyzed 9700 / 10000 datasets.
# analyzed 9710 / 10000 datasets.
# analyzed 9720 / 10000 datasets.
# analyzed 9730 / 10000 datasets.
# analyzed 9740 / 10000 datasets.
# analyzed 9750 / 10000 datasets.
# analyzed 9760 / 10000 datasets.
# analyzed 9770 / 10000 datasets.
# analyzed 9780 / 10000 datasets.
# analyzed 9790 / 10000 datasets.
# analyzed 9800 / 10000 datasets.
# analyzed 9810 / 10000 datasets.
# analyzed 9820 / 10000 datasets.
# analyzed 9830 / 10000 datasets.
# analyzed 9840 / 10000 datasets.
# analyzed 9850 / 10000 datasets.
# analyzed 9860 / 10000 datasets.
# analyzed 9870 / 10000 datasets.
# analyzed 9880 / 10000 datasets.
# analyzed 9890 / 10000 datasets.
# analyzed 9900 / 10000 datasets.
# analyzed 9910 / 10000 datasets.
# analyzed 9920 / 10000 datasets.
# analyzed 9930 / 10000 datasets.
# analyzed 9940 / 10000 datasets.
# analyzed 9950 / 10000 datasets.
# analyzed 9960 / 10000 datasets.
# analyzed 9970 / 10000 datasets.
# analyzed 9980 / 10000 datasets.
# analyzed 9990 / 10000 datasets.

# %%
# in order to visualize the TS distribution under the background-only hypothesis
# we fill the TS samples into a histogram

import cPickle as pickle
with open('background_trials.pickle', 'wb') as f:
    pickle.dump(results_pseudo_data, f, protocol=pickle.HIGHEST_PROTOCOL)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
plt.hist(results_pseudo_data[2],bins=50, normed=True, label="bg-only injected")

ax.set_yscale('log')
ax.set_ylim([1.e-4, 2])
ax.set_xlabel('test-statistic', fontsize=20)
ax.set_ylabel('pdf', fontsize=20)
for axis in ['top','bottom','left','right']: 
    ax.spines[axis].set_linewidth(1.5)
    ax.spines[axis].set_color('0.0')

ax.tick_params(axis='both', which='both', width=1.5, colors='0.0', labelsize=20)
ax.yaxis.set_ticks_position('both')
ax.set_xlim([0.0, 25.0])
plt.legend(bbox_to_anchor=[0.99, 0.99], loc='upper right', prop={'size':13}, ncol=1, fancybox=True)

plt.show()

# none of our samples exceeds the observed TS value of 23.2.
# thus our estimated p-value would be 0. 
# more trials are needed. typically computed on computer clusters.
# with 10^4 trials one can only bound the p-value to be smaller than ~3 x 10^-4

# %%
# what's the distribution of the TS assuming the "true" set of parameters?
# (i.e. is our observed value "typical" given the parameter values that were used to generate the data?)

# Thus we recompute the same TS value as above, but now we generate the pseudo data from the 
# true parameter values
# obviously there are not known before the experiment (and technically not even after ...)
# However sometimes one has a good guess what they should be from theory considerations.
# The "power" of a test is a good metric when designing experiments
results_pseudo_data_H0sig = ana.get_distributions_from_pseudo_data(bins, pars_mc, [pars_H0[0]], pars_H0[1:], pars_nature, 10000)
# Out:
# analyzed 0 / 10000 datasets.
# analyzed 10 / 10000 datasets.
# analyzed 20 / 10000 datasets.
# analyzed 30 / 10000 datasets.
# analyzed 40 / 10000 datasets.
# analyzed 50 / 10000 datasets.
# analyzed 60 / 10000 datasets.
# analyzed 70 / 10000 datasets.
# analyzed 80 / 10000 datasets.
# analyzed 90 / 10000 datasets.
# analyzed 100 / 10000 datasets.
# analyzed 110 / 10000 datasets.
# analyzed 120 / 10000 datasets.
# analyzed 130 / 10000 datasets.
# analyzed 140 / 10000 datasets.
# analyzed 150 / 10000 datasets.
# analyzed 160 / 10000 datasets.
# analyzed 170 / 10000 datasets.
# analyzed 180 / 10000 datasets.
# analyzed 190 / 10000 datasets.
# analyzed 200 / 10000 datasets.
# analyzed 210 / 10000 datasets.
# analyzed 220 / 10000 datasets.
# analyzed 230 / 10000 datasets.
# analyzed 240 / 10000 datasets.
# analyzed 250 / 10000 datasets.
# analyzed 260 / 10000 datasets.
# analyzed 270 / 10000 datasets.
# analyzed 280 / 10000 datasets.
# analyzed 290 / 10000 datasets.
# analyzed 300 / 10000 datasets.
# analyzed 310 / 10000 datasets.
# analyzed 320 / 10000 datasets.
# analyzed 330 / 10000 datasets.
# analyzed 340 / 10000 datasets.
# analyzed 350 / 10000 datasets.
# analyzed 360 / 10000 datasets.
# analyzed 370 / 10000 datasets.
# analyzed 380 / 10000 datasets.
# analyzed 390 / 10000 datasets.
# analyzed 400 / 10000 datasets.
# analyzed 410 / 10000 datasets.
# analyzed 420 / 10000 datasets.
# analyzed 430 / 10000 datasets.
# analyzed 440 / 10000 datasets.
# analyzed 450 / 10000 datasets.
# analyzed 460 / 10000 datasets.
# analyzed 470 / 10000 datasets.
# analyzed 480 / 10000 datasets.
# analyzed 490 / 10000 datasets.
# analyzed 500 / 10000 datasets.
# analyzed 510 / 10000 datasets.
# analyzed 520 / 10000 datasets.
# analyzed 530 / 10000 datasets.
# analyzed 540 / 10000 datasets.
# analyzed 550 / 10000 datasets.
# analyzed 560 / 10000 datasets.
# analyzed 570 / 10000 datasets.
# analyzed 580 / 10000 datasets.
# analyzed 590 / 10000 datasets.
# analyzed 600 / 10000 datasets.
# analyzed 610 / 10000 datasets.
# analyzed 620 / 10000 datasets.
# analyzed 630 / 10000 datasets.
# analyzed 640 / 10000 datasets.
# analyzed 650 / 10000 datasets.
# analyzed 660 / 10000 datasets.
# analyzed 670 / 10000 datasets.
# analyzed 680 / 10000 datasets.
# analyzed 690 / 10000 datasets.
# analyzed 700 / 10000 datasets.
# analyzed 710 / 10000 datasets.
# analyzed 720 / 10000 datasets.
# analyzed 730 / 10000 datasets.
# analyzed 740 / 10000 datasets.
# analyzed 750 / 10000 datasets.
# analyzed 760 / 10000 datasets.
# analyzed 770 / 10000 datasets.
# analyzed 780 / 10000 datasets.
# analyzed 790 / 10000 datasets.
# analyzed 800 / 10000 datasets.
# analyzed 810 / 10000 datasets.
# analyzed 820 / 10000 datasets.
# analyzed 830 / 10000 datasets.
# analyzed 840 / 10000 datasets.
# analyzed 850 / 10000 datasets.
# analyzed 860 / 10000 datasets.
# analyzed 870 / 10000 datasets.
# analyzed 880 / 10000 datasets.
# analyzed 890 / 10000 datasets.
# analyzed 900 / 10000 datasets.
# analyzed 910 / 10000 datasets.
# analyzed 920 / 10000 datasets.
# analyzed 930 / 10000 datasets.
# analyzed 940 / 10000 datasets.
# analyzed 950 / 10000 datasets.
# analyzed 960 / 10000 datasets.
# analyzed 970 / 10000 datasets.
# analyzed 980 / 10000 datasets.
# analyzed 990 / 10000 datasets.
# analyzed 1000 / 10000 datasets.
# analyzed 1010 / 10000 datasets.
# analyzed 1020 / 10000 datasets.
# analyzed 1030 / 10000 datasets.
# analyzed 1040 / 10000 datasets.
# analyzed 1050 / 10000 datasets.
# analyzed 1060 / 10000 datasets.
# analyzed 1070 / 10000 datasets.
# analyzed 1080 / 10000 datasets.
# analyzed 1090 / 10000 datasets.
# analyzed 1100 / 10000 datasets.
# analyzed 1110 / 10000 datasets.
# analyzed 1120 / 10000 datasets.
# analyzed 1130 / 10000 datasets.
# analyzed 1140 / 10000 datasets.
# analyzed 1150 / 10000 datasets.
# analyzed 1160 / 10000 datasets.
# analyzed 1170 / 10000 datasets.
# analyzed 1180 / 10000 datasets.
# analyzed 1190 / 10000 datasets.
# analyzed 1200 / 10000 datasets.
# analyzed 1210 / 10000 datasets.
# analyzed 1220 / 10000 datasets.
# analyzed 1230 / 10000 datasets.
# analyzed 1240 / 10000 datasets.
# analyzed 1250 / 10000 datasets.
# analyzed 1260 / 10000 datasets.
# analyzed 1270 / 10000 datasets.
# analyzed 1280 / 10000 datasets.
# analyzed 1290 / 10000 datasets.
# analyzed 1300 / 10000 datasets.
# analyzed 1310 / 10000 datasets.
# analyzed 1320 / 10000 datasets.
# analyzed 1330 / 10000 datasets.
# analyzed 1340 / 10000 datasets.
# analyzed 1350 / 10000 datasets.
# analyzed 1360 / 10000 datasets.
# analyzed 1370 / 10000 datasets.
# analyzed 1380 / 10000 datasets.
# analyzed 1390 / 10000 datasets.
# analyzed 1400 / 10000 datasets.
# analyzed 1410 / 10000 datasets.
# analyzed 1420 / 10000 datasets.
# analyzed 1430 / 10000 datasets.
# analyzed 1440 / 10000 datasets.
# analyzed 1450 / 10000 datasets.
# analyzed 1460 / 10000 datasets.
# analyzed 1470 / 10000 datasets.
# analyzed 1480 / 10000 datasets.
# analyzed 1490 / 10000 datasets.
# analyzed 1500 / 10000 datasets.
# analyzed 1510 / 10000 datasets.
# analyzed 1520 / 10000 datasets.
# analyzed 1530 / 10000 datasets.
# analyzed 1540 / 10000 datasets.
# analyzed 1550 / 10000 datasets.
# analyzed 1560 / 10000 datasets.
# analyzed 1570 / 10000 datasets.
# analyzed 1580 / 10000 datasets.
# analyzed 1590 / 10000 datasets.
# analyzed 1600 / 10000 datasets.
# analyzed 1610 / 10000 datasets.
# analyzed 1620 / 10000 datasets.
# analyzed 1630 / 10000 datasets.
# analyzed 1640 / 10000 datasets.
# analyzed 1650 / 10000 datasets.
# analyzed 1660 / 10000 datasets.
# analyzed 1670 / 10000 datasets.
# analyzed 1680 / 10000 datasets.
# analyzed 1690 / 10000 datasets.
# analyzed 1700 / 10000 datasets.
# analyzed 1710 / 10000 datasets.
# analyzed 1720 / 10000 datasets.
# analyzed 1730 / 10000 datasets.
# analyzed 1740 / 10000 datasets.
# analyzed 1750 / 10000 datasets.
# analyzed 1760 / 10000 datasets.
# analyzed 1770 / 10000 datasets.
# analyzed 1780 / 10000 datasets.
# analyzed 1790 / 10000 datasets.
# analyzed 1800 / 10000 datasets.
# analyzed 1810 / 10000 datasets.
# analyzed 1820 / 10000 datasets.
# analyzed 1830 / 10000 datasets.
# analyzed 1840 / 10000 datasets.
# analyzed 1850 / 10000 datasets.
# analyzed 1860 / 10000 datasets.
# analyzed 1870 / 10000 datasets.
# analyzed 1880 / 10000 datasets.
# analyzed 1890 / 10000 datasets.
# analyzed 1900 / 10000 datasets.
# analyzed 1910 / 10000 datasets.
# analyzed 1920 / 10000 datasets.
# analyzed 1930 / 10000 datasets.
# analyzed 1940 / 10000 datasets.
# analyzed 1950 / 10000 datasets.
# analyzed 1960 / 10000 datasets.
# analyzed 1970 / 10000 datasets.
# analyzed 1980 / 10000 datasets.
# analyzed 1990 / 10000 datasets.
# analyzed 2000 / 10000 datasets.
# analyzed 2010 / 10000 datasets.
# analyzed 2020 / 10000 datasets.
# analyzed 2030 / 10000 datasets.
# analyzed 2040 / 10000 datasets.
# analyzed 2050 / 10000 datasets.
# analyzed 2060 / 10000 datasets.
# analyzed 2070 / 10000 datasets.
# analyzed 2080 / 10000 datasets.
# analyzed 2090 / 10000 datasets.
# analyzed 2100 / 10000 datasets.
# analyzed 2110 / 10000 datasets.
# analyzed 2120 / 10000 datasets.
# analyzed 2130 / 10000 datasets.
# analyzed 2140 / 10000 datasets.
# analyzed 2150 / 10000 datasets.
# analyzed 2160 / 10000 datasets.
# analyzed 2170 / 10000 datasets.
# analyzed 2180 / 10000 datasets.
# analyzed 2190 / 10000 datasets.
# analyzed 2200 / 10000 datasets.
# analyzed 2210 / 10000 datasets.
# analyzed 2220 / 10000 datasets.
# analyzed 2230 / 10000 datasets.
# analyzed 2240 / 10000 datasets.
# analyzed 2250 / 10000 datasets.
# analyzed 2260 / 10000 datasets.
# analyzed 2270 / 10000 datasets.
# analyzed 2280 / 10000 datasets.
# analyzed 2290 / 10000 datasets.
# analyzed 2300 / 10000 datasets.
# analyzed 2310 / 10000 datasets.
# analyzed 2320 / 10000 datasets.
# analyzed 2330 / 10000 datasets.
# analyzed 2340 / 10000 datasets.
# analyzed 2350 / 10000 datasets.
# analyzed 2360 / 10000 datasets.
# analyzed 2370 / 10000 datasets.
# analyzed 2380 / 10000 datasets.
# analyzed 2390 / 10000 datasets.
# analyzed 2400 / 10000 datasets.
# analyzed 2410 / 10000 datasets.
# analyzed 2420 / 10000 datasets.
# analyzed 2430 / 10000 datasets.
# analyzed 2440 / 10000 datasets.
# analyzed 2450 / 10000 datasets.
# analyzed 2460 / 10000 datasets.
# analyzed 2470 / 10000 datasets.
# analyzed 2480 / 10000 datasets.
# analyzed 2490 / 10000 datasets.
# analyzed 2500 / 10000 datasets.
# analyzed 2510 / 10000 datasets.
# analyzed 2520 / 10000 datasets.
# analyzed 2530 / 10000 datasets.
# analyzed 2540 / 10000 datasets.
# analyzed 2550 / 10000 datasets.
# analyzed 2560 / 10000 datasets.
# analyzed 2570 / 10000 datasets.
# analyzed 2580 / 10000 datasets.
# analyzed 2590 / 10000 datasets.
# analyzed 2600 / 10000 datasets.
# analyzed 2610 / 10000 datasets.
# analyzed 2620 / 10000 datasets.
# analyzed 2630 / 10000 datasets.
# analyzed 2640 / 10000 datasets.
# analyzed 2650 / 10000 datasets.
# analyzed 2660 / 10000 datasets.
# analyzed 2670 / 10000 datasets.
# analyzed 2680 / 10000 datasets.
# analyzed 2690 / 10000 datasets.
# analyzed 2700 / 10000 datasets.
# analyzed 2710 / 10000 datasets.
# analyzed 2720 / 10000 datasets.
# analyzed 2730 / 10000 datasets.
# analyzed 2740 / 10000 datasets.
# analyzed 2750 / 10000 datasets.
# analyzed 2760 / 10000 datasets.
# analyzed 2770 / 10000 datasets.
# analyzed 2780 / 10000 datasets.
# analyzed 2790 / 10000 datasets.
# analyzed 2800 / 10000 datasets.
# analyzed 2810 / 10000 datasets.
# analyzed 2820 / 10000 datasets.
# analyzed 2830 / 10000 datasets.
# analyzed 2840 / 10000 datasets.
# analyzed 2850 / 10000 datasets.
# analyzed 2860 / 10000 datasets.
# analyzed 2870 / 10000 datasets.
# analyzed 2880 / 10000 datasets.
# analyzed 2890 / 10000 datasets.
# analyzed 2900 / 10000 datasets.
# analyzed 2910 / 10000 datasets.
# analyzed 2920 / 10000 datasets.
# analyzed 2930 / 10000 datasets.
# analyzed 2940 / 10000 datasets.
# analyzed 2950 / 10000 datasets.
# analyzed 2960 / 10000 datasets.
# analyzed 2970 / 10000 datasets.
# analyzed 2980 / 10000 datasets.
# analyzed 2990 / 10000 datasets.
# analyzed 3000 / 10000 datasets.
# analyzed 3010 / 10000 datasets.
# analyzed 3020 / 10000 datasets.
# analyzed 3030 / 10000 datasets.
# analyzed 3040 / 10000 datasets.
# analyzed 3050 / 10000 datasets.
# analyzed 3060 / 10000 datasets.
# analyzed 3070 / 10000 datasets.
# analyzed 3080 / 10000 datasets.
# analyzed 3090 / 10000 datasets.
# analyzed 3100 / 10000 datasets.
# analyzed 3110 / 10000 datasets.
# analyzed 3120 / 10000 datasets.
# analyzed 3130 / 10000 datasets.
# analyzed 3140 / 10000 datasets.
# analyzed 3150 / 10000 datasets.
# analyzed 3160 / 10000 datasets.
# analyzed 3170 / 10000 datasets.
# analyzed 3180 / 10000 datasets.
# analyzed 3190 / 10000 datasets.
# analyzed 3200 / 10000 datasets.
# analyzed 3210 / 10000 datasets.
# analyzed 3220 / 10000 datasets.
# analyzed 3230 / 10000 datasets.
# analyzed 3240 / 10000 datasets.
# analyzed 3250 / 10000 datasets.
# analyzed 3260 / 10000 datasets.
# analyzed 3270 / 10000 datasets.
# analyzed 3280 / 10000 datasets.
# analyzed 3290 / 10000 datasets.
# analyzed 3300 / 10000 datasets.
# analyzed 3310 / 10000 datasets.
# analyzed 3320 / 10000 datasets.
# analyzed 3330 / 10000 datasets.
# analyzed 3340 / 10000 datasets.
# analyzed 3350 / 10000 datasets.
# analyzed 3360 / 10000 datasets.
# analyzed 3370 / 10000 datasets.
# analyzed 3380 / 10000 datasets.
# analyzed 3390 / 10000 datasets.
# analyzed 3400 / 10000 datasets.
# analyzed 3410 / 10000 datasets.
# analyzed 3420 / 10000 datasets.
# analyzed 3430 / 10000 datasets.
# analyzed 3440 / 10000 datasets.
# analyzed 3450 / 10000 datasets.
# analyzed 3460 / 10000 datasets.
# analyzed 3470 / 10000 datasets.
# analyzed 3480 / 10000 datasets.
# analyzed 3490 / 10000 datasets.
# analyzed 3500 / 10000 datasets.
# analyzed 3510 / 10000 datasets.
# analyzed 3520 / 10000 datasets.
# analyzed 3530 / 10000 datasets.
# analyzed 3540 / 10000 datasets.
# analyzed 3550 / 10000 datasets.
# analyzed 3560 / 10000 datasets.
# analyzed 3570 / 10000 datasets.
# analyzed 3580 / 10000 datasets.
# analyzed 3590 / 10000 datasets.
# analyzed 3600 / 10000 datasets.
# analyzed 3610 / 10000 datasets.
# analyzed 3620 / 10000 datasets.
# analyzed 3630 / 10000 datasets.
# analyzed 3640 / 10000 datasets.
# analyzed 3650 / 10000 datasets.
# analyzed 3660 / 10000 datasets.
# analyzed 3670 / 10000 datasets.
# analyzed 3680 / 10000 datasets.
# analyzed 3690 / 10000 datasets.
# analyzed 3700 / 10000 datasets.
# analyzed 3710 / 10000 datasets.
# analyzed 3720 / 10000 datasets.
# analyzed 3730 / 10000 datasets.
# analyzed 3740 / 10000 datasets.
# analyzed 3750 / 10000 datasets.
# analyzed 3760 / 10000 datasets.
# analyzed 3770 / 10000 datasets.
# analyzed 3780 / 10000 datasets.
# analyzed 3790 / 10000 datasets.
# analyzed 3800 / 10000 datasets.
# analyzed 3810 / 10000 datasets.
# analyzed 3820 / 10000 datasets.
# analyzed 3830 / 10000 datasets.
# analyzed 3840 / 10000 datasets.
# analyzed 3850 / 10000 datasets.
# analyzed 3860 / 10000 datasets.
# analyzed 3870 / 10000 datasets.
# analyzed 3880 / 10000 datasets.
# analyzed 3890 / 10000 datasets.
# analyzed 3900 / 10000 datasets.
# analyzed 3910 / 10000 datasets.
# analyzed 3920 / 10000 datasets.
# analyzed 3930 / 10000 datasets.
# analyzed 3940 / 10000 datasets.
# analyzed 3950 / 10000 datasets.
# analyzed 3960 / 10000 datasets.
# analyzed 3970 / 10000 datasets.
# analyzed 3980 / 10000 datasets.
# analyzed 3990 / 10000 datasets.
# analyzed 4000 / 10000 datasets.
# analyzed 4010 / 10000 datasets.
# analyzed 4020 / 10000 datasets.
# analyzed 4030 / 10000 datasets.
# analyzed 4040 / 10000 datasets.
# analyzed 4050 / 10000 datasets.
# analyzed 4060 / 10000 datasets.
# analyzed 4070 / 10000 datasets.
# analyzed 4080 / 10000 datasets.
# analyzed 4090 / 10000 datasets.
# analyzed 4100 / 10000 datasets.
# analyzed 4110 / 10000 datasets.
# analyzed 4120 / 10000 datasets.
# analyzed 4130 / 10000 datasets.
# analyzed 4140 / 10000 datasets.
# analyzed 4150 / 10000 datasets.
# analyzed 4160 / 10000 datasets.
# analyzed 4170 / 10000 datasets.
# analyzed 4180 / 10000 datasets.
# analyzed 4190 / 10000 datasets.
# analyzed 4200 / 10000 datasets.
# analyzed 4210 / 10000 datasets.
# analyzed 4220 / 10000 datasets.
# analyzed 4230 / 10000 datasets.
# analyzed 4240 / 10000 datasets.
# analyzed 4250 / 10000 datasets.
# analyzed 4260 / 10000 datasets.
# analyzed 4270 / 10000 datasets.
# analyzed 4280 / 10000 datasets.
# analyzed 4290 / 10000 datasets.
# analyzed 4300 / 10000 datasets.
# analyzed 4310 / 10000 datasets.
# analyzed 4320 / 10000 datasets.
# analyzed 4330 / 10000 datasets.
# analyzed 4340 / 10000 datasets.
# analyzed 4350 / 10000 datasets.
# analyzed 4360 / 10000 datasets.
# analyzed 4370 / 10000 datasets.
# analyzed 4380 / 10000 datasets.
# analyzed 4390 / 10000 datasets.
# analyzed 4400 / 10000 datasets.
# analyzed 4410 / 10000 datasets.
# analyzed 4420 / 10000 datasets.
# analyzed 4430 / 10000 datasets.
# analyzed 4440 / 10000 datasets.
# analyzed 4450 / 10000 datasets.
# analyzed 4460 / 10000 datasets.
# analyzed 4470 / 10000 datasets.
# analyzed 4480 / 10000 datasets.
# analyzed 4490 / 10000 datasets.
# analyzed 4500 / 10000 datasets.
# analyzed 4510 / 10000 datasets.
# analyzed 4520 / 10000 datasets.
# analyzed 4530 / 10000 datasets.
# analyzed 4540 / 10000 datasets.
# analyzed 4550 / 10000 datasets.
# analyzed 4560 / 10000 datasets.
# analyzed 4570 / 10000 datasets.
# analyzed 4580 / 10000 datasets.
# analyzed 4590 / 10000 datasets.
# analyzed 4600 / 10000 datasets.
# analyzed 4610 / 10000 datasets.
# analyzed 4620 / 10000 datasets.
# analyzed 4630 / 10000 datasets.
# analyzed 4640 / 10000 datasets.
# analyzed 4650 / 10000 datasets.
# analyzed 4660 / 10000 datasets.
# analyzed 4670 / 10000 datasets.
# analyzed 4680 / 10000 datasets.
# analyzed 4690 / 10000 datasets.
# analyzed 4700 / 10000 datasets.
# analyzed 4710 / 10000 datasets.
# analyzed 4720 / 10000 datasets.
# analyzed 4730 / 10000 datasets.
# analyzed 4740 / 10000 datasets.
# analyzed 4750 / 10000 datasets.
# analyzed 4760 / 10000 datasets.
# analyzed 4770 / 10000 datasets.
# analyzed 4780 / 10000 datasets.
# analyzed 4790 / 10000 datasets.
# analyzed 4800 / 10000 datasets.
# analyzed 4810 / 10000 datasets.
# analyzed 4820 / 10000 datasets.
# analyzed 4830 / 10000 datasets.
# analyzed 4840 / 10000 datasets.
# analyzed 4850 / 10000 datasets.
# analyzed 4860 / 10000 datasets.
# analyzed 4870 / 10000 datasets.
# analyzed 4880 / 10000 datasets.
# analyzed 4890 / 10000 datasets.
# analyzed 4900 / 10000 datasets.
# analyzed 4910 / 10000 datasets.
# analyzed 4920 / 10000 datasets.
# analyzed 4930 / 10000 datasets.
# analyzed 4940 / 10000 datasets.
# analyzed 4950 / 10000 datasets.
# analyzed 4960 / 10000 datasets.
# analyzed 4970 / 10000 datasets.
# analyzed 4980 / 10000 datasets.
# analyzed 4990 / 10000 datasets.
# analyzed 5000 / 10000 datasets.
# analyzed 5010 / 10000 datasets.
# analyzed 5020 / 10000 datasets.
# analyzed 5030 / 10000 datasets.
# analyzed 5040 / 10000 datasets.
# analyzed 5050 / 10000 datasets.
# analyzed 5060 / 10000 datasets.
# analyzed 5070 / 10000 datasets.
# analyzed 5080 / 10000 datasets.
# analyzed 5090 / 10000 datasets.
# analyzed 5100 / 10000 datasets.
# analyzed 5110 / 10000 datasets.
# analyzed 5120 / 10000 datasets.
# analyzed 5130 / 10000 datasets.
# analyzed 5140 / 10000 datasets.
# analyzed 5150 / 10000 datasets.
# analyzed 5160 / 10000 datasets.
# analyzed 5170 / 10000 datasets.
# analyzed 5180 / 10000 datasets.
# analyzed 5190 / 10000 datasets.
# analyzed 5200 / 10000 datasets.
# analyzed 5210 / 10000 datasets.
# analyzed 5220 / 10000 datasets.
# analyzed 5230 / 10000 datasets.
# analyzed 5240 / 10000 datasets.
# analyzed 5250 / 10000 datasets.
# analyzed 5260 / 10000 datasets.
# analyzed 5270 / 10000 datasets.
# analyzed 5280 / 10000 datasets.
# analyzed 5290 / 10000 datasets.
# analyzed 5300 / 10000 datasets.
# analyzed 5310 / 10000 datasets.
# analyzed 5320 / 10000 datasets.
# analyzed 5330 / 10000 datasets.
# analyzed 5340 / 10000 datasets.
# analyzed 5350 / 10000 datasets.
# analyzed 5360 / 10000 datasets.
# analyzed 5370 / 10000 datasets.
# analyzed 5380 / 10000 datasets.
# analyzed 5390 / 10000 datasets.
# analyzed 5400 / 10000 datasets.
# analyzed 5410 / 10000 datasets.
# analyzed 5420 / 10000 datasets.
# analyzed 5430 / 10000 datasets.
# analyzed 5440 / 10000 datasets.
# analyzed 5450 / 10000 datasets.
# analyzed 5460 / 10000 datasets.
# analyzed 5470 / 10000 datasets.
# analyzed 5480 / 10000 datasets.
# analyzed 5490 / 10000 datasets.
# analyzed 5500 / 10000 datasets.
# analyzed 5510 / 10000 datasets.
# analyzed 5520 / 10000 datasets.
# analyzed 5530 / 10000 datasets.
# analyzed 5540 / 10000 datasets.
# analyzed 5550 / 10000 datasets.
# analyzed 5560 / 10000 datasets.
# analyzed 5570 / 10000 datasets.
# analyzed 5580 / 10000 datasets.
# analyzed 5590 / 10000 datasets.
# analyzed 5600 / 10000 datasets.
# analyzed 5610 / 10000 datasets.
# analyzed 5620 / 10000 datasets.
# analyzed 5630 / 10000 datasets.
# analyzed 5640 / 10000 datasets.
# analyzed 5650 / 10000 datasets.
# analyzed 5660 / 10000 datasets.
# analyzed 5670 / 10000 datasets.
# analyzed 5680 / 10000 datasets.
# analyzed 5690 / 10000 datasets.
# analyzed 5700 / 10000 datasets.
# analyzed 5710 / 10000 datasets.
# analyzed 5720 / 10000 datasets.
# analyzed 5730 / 10000 datasets.
# analyzed 5740 / 10000 datasets.
# analyzed 5750 / 10000 datasets.
# analyzed 5760 / 10000 datasets.
# analyzed 5770 / 10000 datasets.
# analyzed 5780 / 10000 datasets.
# analyzed 5790 / 10000 datasets.
# analyzed 5800 / 10000 datasets.
# analyzed 5810 / 10000 datasets.
# analyzed 5820 / 10000 datasets.
# analyzed 5830 / 10000 datasets.
# analyzed 5840 / 10000 datasets.
# analyzed 5850 / 10000 datasets.
# analyzed 5860 / 10000 datasets.
# analyzed 5870 / 10000 datasets.
# analyzed 5880 / 10000 datasets.
# analyzed 5890 / 10000 datasets.
# analyzed 5900 / 10000 datasets.
# analyzed 5910 / 10000 datasets.
# analyzed 5920 / 10000 datasets.
# analyzed 5930 / 10000 datasets.
# analyzed 5940 / 10000 datasets.
# analyzed 5950 / 10000 datasets.
# analyzed 5960 / 10000 datasets.
# analyzed 5970 / 10000 datasets.
# analyzed 5980 / 10000 datasets.
# analyzed 5990 / 10000 datasets.
# analyzed 6000 / 10000 datasets.
# analyzed 6010 / 10000 datasets.
# analyzed 6020 / 10000 datasets.
# analyzed 6030 / 10000 datasets.
# analyzed 6040 / 10000 datasets.
# analyzed 6050 / 10000 datasets.
# analyzed 6060 / 10000 datasets.
# analyzed 6070 / 10000 datasets.
# analyzed 6080 / 10000 datasets.
# analyzed 6090 / 10000 datasets.
# analyzed 6100 / 10000 datasets.
# analyzed 6110 / 10000 datasets.
# analyzed 6120 / 10000 datasets.
# analyzed 6130 / 10000 datasets.
# analyzed 6140 / 10000 datasets.
# analyzed 6150 / 10000 datasets.
# analyzed 6160 / 10000 datasets.
# analyzed 6170 / 10000 datasets.
# analyzed 6180 / 10000 datasets.
# analyzed 6190 / 10000 datasets.
# analyzed 6200 / 10000 datasets.
# analyzed 6210 / 10000 datasets.
# analyzed 6220 / 10000 datasets.
# analyzed 6230 / 10000 datasets.
# analyzed 6240 / 10000 datasets.
# analyzed 6250 / 10000 datasets.
# analyzed 6260 / 10000 datasets.
# analyzed 6270 / 10000 datasets.
# analyzed 6280 / 10000 datasets.
# analyzed 6290 / 10000 datasets.
# analyzed 6300 / 10000 datasets.
# analyzed 6310 / 10000 datasets.
# analyzed 6320 / 10000 datasets.
# analyzed 6330 / 10000 datasets.
# analyzed 6340 / 10000 datasets.
# analyzed 6350 / 10000 datasets.
# analyzed 6360 / 10000 datasets.
# analyzed 6370 / 10000 datasets.
# analyzed 6380 / 10000 datasets.
# analyzed 6390 / 10000 datasets.
# analyzed 6400 / 10000 datasets.
# analyzed 6410 / 10000 datasets.
# analyzed 6420 / 10000 datasets.
# analyzed 6430 / 10000 datasets.
# analyzed 6440 / 10000 datasets.
# analyzed 6450 / 10000 datasets.
# analyzed 6460 / 10000 datasets.
# analyzed 6470 / 10000 datasets.
# analyzed 6480 / 10000 datasets.
# analyzed 6490 / 10000 datasets.
# analyzed 6500 / 10000 datasets.
# analyzed 6510 / 10000 datasets.
# analyzed 6520 / 10000 datasets.
# analyzed 6530 / 10000 datasets.
# analyzed 6540 / 10000 datasets.
# analyzed 6550 / 10000 datasets.
# analyzed 6560 / 10000 datasets.
# analyzed 6570 / 10000 datasets.
# analyzed 6580 / 10000 datasets.
# analyzed 6590 / 10000 datasets.
# analyzed 6600 / 10000 datasets.
# analyzed 6610 / 10000 datasets.
# analyzed 6620 / 10000 datasets.
# analyzed 6630 / 10000 datasets.
# analyzed 6640 / 10000 datasets.
# analyzed 6650 / 10000 datasets.
# analyzed 6660 / 10000 datasets.
# analyzed 6670 / 10000 datasets.
# analyzed 6680 / 10000 datasets.
# analyzed 6690 / 10000 datasets.
# analyzed 6700 / 10000 datasets.
# analyzed 6710 / 10000 datasets.
# analyzed 6720 / 10000 datasets.
# analyzed 6730 / 10000 datasets.
# analyzed 6740 / 10000 datasets.
# analyzed 6750 / 10000 datasets.
# analyzed 6760 / 10000 datasets.
# analyzed 6770 / 10000 datasets.
# analyzed 6780 / 10000 datasets.
# analyzed 6790 / 10000 datasets.
# analyzed 6800 / 10000 datasets.
# analyzed 6810 / 10000 datasets.
# analyzed 6820 / 10000 datasets.
# analyzed 6830 / 10000 datasets.
# analyzed 6840 / 10000 datasets.
# analyzed 6850 / 10000 datasets.
# analyzed 6860 / 10000 datasets.
# analyzed 6870 / 10000 datasets.
# analyzed 6880 / 10000 datasets.
# analyzed 6890 / 10000 datasets.
# analyzed 6900 / 10000 datasets.
# analyzed 6910 / 10000 datasets.
# analyzed 6920 / 10000 datasets.
# analyzed 6930 / 10000 datasets.
# analyzed 6940 / 10000 datasets.
# analyzed 6950 / 10000 datasets.
# analyzed 6960 / 10000 datasets.
# analyzed 6970 / 10000 datasets.
# analyzed 6980 / 10000 datasets.
# analyzed 6990 / 10000 datasets.
# analyzed 7000 / 10000 datasets.
# analyzed 7010 / 10000 datasets.
# analyzed 7020 / 10000 datasets.
# analyzed 7030 / 10000 datasets.
# analyzed 7040 / 10000 datasets.
# analyzed 7050 / 10000 datasets.
# analyzed 7060 / 10000 datasets.
# analyzed 7070 / 10000 datasets.
# analyzed 7080 / 10000 datasets.
# analyzed 7090 / 10000 datasets.
# analyzed 7100 / 10000 datasets.
# analyzed 7110 / 10000 datasets.
# analyzed 7120 / 10000 datasets.
# analyzed 7130 / 10000 datasets.
# analyzed 7140 / 10000 datasets.
# analyzed 7150 / 10000 datasets.
# analyzed 7160 / 10000 datasets.
# analyzed 7170 / 10000 datasets.
# analyzed 7180 / 10000 datasets.
# analyzed 7190 / 10000 datasets.
# analyzed 7200 / 10000 datasets.
# analyzed 7210 / 10000 datasets.
# analyzed 7220 / 10000 datasets.
# analyzed 7230 / 10000 datasets.
# analyzed 7240 / 10000 datasets.
# analyzed 7250 / 10000 datasets.
# analyzed 7260 / 10000 datasets.
# analyzed 7270 / 10000 datasets.
# analyzed 7280 / 10000 datasets.
# analyzed 7290 / 10000 datasets.
# analyzed 7300 / 10000 datasets.
# analyzed 7310 / 10000 datasets.
# analyzed 7320 / 10000 datasets.
# analyzed 7330 / 10000 datasets.
# analyzed 7340 / 10000 datasets.
# analyzed 7350 / 10000 datasets.
# analyzed 7360 / 10000 datasets.
# analyzed 7370 / 10000 datasets.
# analyzed 7380 / 10000 datasets.
# analyzed 7390 / 10000 datasets.
# analyzed 7400 / 10000 datasets.
# analyzed 7410 / 10000 datasets.
# analyzed 7420 / 10000 datasets.
# analyzed 7430 / 10000 datasets.
# analyzed 7440 / 10000 datasets.
# analyzed 7450 / 10000 datasets.
# analyzed 7460 / 10000 datasets.
# analyzed 7470 / 10000 datasets.
# analyzed 7480 / 10000 datasets.
# analyzed 7490 / 10000 datasets.
# analyzed 7500 / 10000 datasets.
# analyzed 7510 / 10000 datasets.
# analyzed 7520 / 10000 datasets.
# analyzed 7530 / 10000 datasets.
# analyzed 7540 / 10000 datasets.
# analyzed 7550 / 10000 datasets.
# analyzed 7560 / 10000 datasets.
# analyzed 7570 / 10000 datasets.
# analyzed 7580 / 10000 datasets.
# analyzed 7590 / 10000 datasets.
# analyzed 7600 / 10000 datasets.
# analyzed 7610 / 10000 datasets.
# analyzed 7620 / 10000 datasets.
# analyzed 7630 / 10000 datasets.
# analyzed 7640 / 10000 datasets.
# analyzed 7650 / 10000 datasets.
# analyzed 7660 / 10000 datasets.
# analyzed 7670 / 10000 datasets.
# analyzed 7680 / 10000 datasets.
# analyzed 7690 / 10000 datasets.
# analyzed 7700 / 10000 datasets.
# analyzed 7710 / 10000 datasets.
# analyzed 7720 / 10000 datasets.
# analyzed 7730 / 10000 datasets.
# analyzed 7740 / 10000 datasets.
# analyzed 7750 / 10000 datasets.
# analyzed 7760 / 10000 datasets.
# analyzed 7770 / 10000 datasets.
# analyzed 7780 / 10000 datasets.
# analyzed 7790 / 10000 datasets.
# analyzed 7800 / 10000 datasets.
# analyzed 7810 / 10000 datasets.
# analyzed 7820 / 10000 datasets.
# analyzed 7830 / 10000 datasets.
# analyzed 7840 / 10000 datasets.
# analyzed 7850 / 10000 datasets.
# analyzed 7860 / 10000 datasets.
# analyzed 7870 / 10000 datasets.
# analyzed 7880 / 10000 datasets.
# analyzed 7890 / 10000 datasets.
# analyzed 7900 / 10000 datasets.
# analyzed 7910 / 10000 datasets.
# analyzed 7920 / 10000 datasets.
# analyzed 7930 / 10000 datasets.
# analyzed 7940 / 10000 datasets.
# analyzed 7950 / 10000 datasets.
# analyzed 7960 / 10000 datasets.
# analyzed 7970 / 10000 datasets.
# analyzed 7980 / 10000 datasets.
# analyzed 7990 / 10000 datasets.
# analyzed 8000 / 10000 datasets.
# analyzed 8010 / 10000 datasets.
# analyzed 8020 / 10000 datasets.
# analyzed 8030 / 10000 datasets.
# analyzed 8040 / 10000 datasets.
# analyzed 8050 / 10000 datasets.
# analyzed 8060 / 10000 datasets.
# analyzed 8070 / 10000 datasets.
# analyzed 8080 / 10000 datasets.
# analyzed 8090 / 10000 datasets.
# analyzed 8100 / 10000 datasets.
# analyzed 8110 / 10000 datasets.
# analyzed 8120 / 10000 datasets.
# analyzed 8130 / 10000 datasets.
# analyzed 8140 / 10000 datasets.
# analyzed 8150 / 10000 datasets.
# analyzed 8160 / 10000 datasets.
# analyzed 8170 / 10000 datasets.
# analyzed 8180 / 10000 datasets.
# analyzed 8190 / 10000 datasets.
# analyzed 8200 / 10000 datasets.
# analyzed 8210 / 10000 datasets.
# analyzed 8220 / 10000 datasets.
# analyzed 8230 / 10000 datasets.
# analyzed 8240 / 10000 datasets.
# analyzed 8250 / 10000 datasets.
# analyzed 8260 / 10000 datasets.
# analyzed 8270 / 10000 datasets.
# analyzed 8280 / 10000 datasets.
# analyzed 8290 / 10000 datasets.
# analyzed 8300 / 10000 datasets.
# analyzed 8310 / 10000 datasets.
# analyzed 8320 / 10000 datasets.
# analyzed 8330 / 10000 datasets.
# analyzed 8340 / 10000 datasets.
# analyzed 8350 / 10000 datasets.
# analyzed 8360 / 10000 datasets.
# analyzed 8370 / 10000 datasets.
# analyzed 8380 / 10000 datasets.
# analyzed 8390 / 10000 datasets.
# analyzed 8400 / 10000 datasets.
# analyzed 8410 / 10000 datasets.
# analyzed 8420 / 10000 datasets.
# analyzed 8430 / 10000 datasets.
# analyzed 8440 / 10000 datasets.
# analyzed 8450 / 10000 datasets.
# analyzed 8460 / 10000 datasets.
# analyzed 8470 / 10000 datasets.
# analyzed 8480 / 10000 datasets.
# analyzed 8490 / 10000 datasets.
# analyzed 8500 / 10000 datasets.
# analyzed 8510 / 10000 datasets.
# analyzed 8520 / 10000 datasets.
# analyzed 8530 / 10000 datasets.
# analyzed 8540 / 10000 datasets.
# analyzed 8550 / 10000 datasets.
# analyzed 8560 / 10000 datasets.
# analyzed 8570 / 10000 datasets.
# analyzed 8580 / 10000 datasets.
# analyzed 8590 / 10000 datasets.
# analyzed 8600 / 10000 datasets.
# analyzed 8610 / 10000 datasets.
# analyzed 8620 / 10000 datasets.
# analyzed 8630 / 10000 datasets.
# analyzed 8640 / 10000 datasets.
# analyzed 8650 / 10000 datasets.
# analyzed 8660 / 10000 datasets.
# analyzed 8670 / 10000 datasets.
# analyzed 8680 / 10000 datasets.
# analyzed 8690 / 10000 datasets.
# analyzed 8700 / 10000 datasets.
# analyzed 8710 / 10000 datasets.
# analyzed 8720 / 10000 datasets.
# analyzed 8730 / 10000 datasets.
# analyzed 8740 / 10000 datasets.
# analyzed 8750 / 10000 datasets.
# analyzed 8760 / 10000 datasets.
# analyzed 8770 / 10000 datasets.
# analyzed 8780 / 10000 datasets.
# analyzed 8790 / 10000 datasets.
# analyzed 8800 / 10000 datasets.
# analyzed 8810 / 10000 datasets.
# analyzed 8820 / 10000 datasets.
# analyzed 8830 / 10000 datasets.
# analyzed 8840 / 10000 datasets.
# analyzed 8850 / 10000 datasets.
# analyzed 8860 / 10000 datasets.
# analyzed 8870 / 10000 datasets.
# analyzed 8880 / 10000 datasets.
# analyzed 8890 / 10000 datasets.
# analyzed 8900 / 10000 datasets.
# analyzed 8910 / 10000 datasets.
# analyzed 8920 / 10000 datasets.
# analyzed 8930 / 10000 datasets.
# analyzed 8940 / 10000 datasets.
# analyzed 8950 / 10000 datasets.
# analyzed 8960 / 10000 datasets.
# analyzed 8970 / 10000 datasets.
# analyzed 8980 / 10000 datasets.
# analyzed 8990 / 10000 datasets.
# analyzed 9000 / 10000 datasets.
# analyzed 9010 / 10000 datasets.
# analyzed 9020 / 10000 datasets.
# analyzed 9030 / 10000 datasets.
# analyzed 9040 / 10000 datasets.
# analyzed 9050 / 10000 datasets.
# analyzed 9060 / 10000 datasets.
# analyzed 9070 / 10000 datasets.
# analyzed 9080 / 10000 datasets.
# analyzed 9090 / 10000 datasets.
# analyzed 9100 / 10000 datasets.
# analyzed 9110 / 10000 datasets.
# analyzed 9120 / 10000 datasets.
# analyzed 9130 / 10000 datasets.
# analyzed 9140 / 10000 datasets.
# analyzed 9150 / 10000 datasets.
# analyzed 9160 / 10000 datasets.
# analyzed 9170 / 10000 datasets.
# analyzed 9180 / 10000 datasets.
# analyzed 9190 / 10000 datasets.
# analyzed 9200 / 10000 datasets.
# analyzed 9210 / 10000 datasets.
# analyzed 9220 / 10000 datasets.
# analyzed 9230 / 10000 datasets.
# analyzed 9240 / 10000 datasets.
# analyzed 9250 / 10000 datasets.
# analyzed 9260 / 10000 datasets.
# analyzed 9270 / 10000 datasets.
# analyzed 9280 / 10000 datasets.
# analyzed 9290 / 10000 datasets.
# analyzed 9300 / 10000 datasets.
# analyzed 9310 / 10000 datasets.
# analyzed 9320 / 10000 datasets.
# analyzed 9330 / 10000 datasets.
# analyzed 9340 / 10000 datasets.
# analyzed 9350 / 10000 datasets.
# analyzed 9360 / 10000 datasets.
# analyzed 9370 / 10000 datasets.
# analyzed 9380 / 10000 datasets.
# analyzed 9390 / 10000 datasets.
# analyzed 9400 / 10000 datasets.
# analyzed 9410 / 10000 datasets.
# analyzed 9420 / 10000 datasets.
# analyzed 9430 / 10000 datasets.
# analyzed 9440 / 10000 datasets.
# analyzed 9450 / 10000 datasets.
# analyzed 9460 / 10000 datasets.
# analyzed 9470 / 10000 datasets.
# analyzed 9480 / 10000 datasets.
# analyzed 9490 / 10000 datasets.
# analyzed 9500 / 10000 datasets.
# analyzed 9510 / 10000 datasets.
# analyzed 9520 / 10000 datasets.
# analyzed 9530 / 10000 datasets.
# analyzed 9540 / 10000 datasets.
# analyzed 9550 / 10000 datasets.
# analyzed 9560 / 10000 datasets.
# analyzed 9570 / 10000 datasets.
# analyzed 9580 / 10000 datasets.
# analyzed 9590 / 10000 datasets.
# analyzed 9600 / 10000 datasets.
# analyzed 9610 / 10000 datasets.
# analyzed 9620 / 10000 datasets.
# analyzed 9630 / 10000 datasets.
# analyzed 9640 / 10000 datasets.
# analyzed 9650 / 10000 datasets.
# analyzed 9660 / 10000 datasets.
# analyzed 9670 / 10000 datasets.
# analyzed 9680 / 10000 datasets.
# analyzed 9690 / 10000 datasets.
# analyzed 9700 / 10000 datasets.
# analyzed 9710 / 10000 datasets.
# analyzed 9720 / 10000 datasets.
# analyzed 9730 / 10000 datasets.
# analyzed 9740 / 10000 datasets.
# analyzed 9750 / 10000 datasets.
# analyzed 9760 / 10000 datasets.
# analyzed 9770 / 10000 datasets.
# analyzed 9780 / 10000 datasets.
# analyzed 9790 / 10000 datasets.
# analyzed 9800 / 10000 datasets.
# analyzed 9810 / 10000 datasets.
# analyzed 9820 / 10000 datasets.
# analyzed 9830 / 10000 datasets.
# analyzed 9840 / 10000 datasets.
# analyzed 9850 / 10000 datasets.
# analyzed 9860 / 10000 datasets.
# analyzed 9870 / 10000 datasets.
# analyzed 9880 / 10000 datasets.
# analyzed 9890 / 10000 datasets.
# analyzed 9900 / 10000 datasets.
# analyzed 9910 / 10000 datasets.
# analyzed 9920 / 10000 datasets.
# analyzed 9930 / 10000 datasets.
# analyzed 9940 / 10000 datasets.
# analyzed 9950 / 10000 datasets.
# analyzed 9960 / 10000 datasets.
# analyzed 9970 / 10000 datasets.
# analyzed 9980 / 10000 datasets.
# analyzed 9990 / 10000 datasets.

# %%
import cPickle as pickle
with open('signal_trials_discoveryTS.pickle', 'wb') as f:
    pickle.dump(results_pseudo_data_H0sig, f, protocol=pickle.HIGHEST_PROTOCOL)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
plt.hist(results_pseudo_data_H0sig[2],bins=50, normed=True, label="signal injected")

ax.set_yscale('log')
ax.set_ylim([1.e-5, 0.1])
ax.set_xlabel('test-statistic', fontsize=20)
ax.set_ylabel('pdf', fontsize=20)
for axis in ['top','bottom','left','right']: 
    ax.spines[axis].set_linewidth(1.5)
    ax.spines[axis].set_color('0.0')

ax.tick_params(axis='both', which='both', width=1.5, colors='0.0', labelsize=20)
ax.yaxis.set_ticks_position('both')
ax.set_xlim([0.0, 150.0])
plt.legend(bbox_to_anchor=[0.99, 0.99], loc='upper right', prop={'size':13}, ncol=1, fancybox=True)

plt.show()

# The observed value 23.2 is pretty much what one would expect given what we injected.

# %%
# Finally we compute the distribution of a different TS.
# H0: astro_norm, astro_gamma = (1.0, 2.0), i.e. nominal MC
# H1: astro_norm, astro_gamma != nominal MC

# such test is useful to define confidence regions which we discuss in the coming lectures.

results_pseudo_data_H1 = ana.get_distributions_from_pseudo_data(bins, pars_mc, [pars_mc[0]], pars_mc[1:], pars_mc,10000)
# Out:
# analyzed 0 / 10000 datasets.
# analyzed 10 / 10000 datasets.
# analyzed 20 / 10000 datasets.
# analyzed 30 / 10000 datasets.
# analyzed 40 / 10000 datasets.
# analyzed 50 / 10000 datasets.
# analyzed 60 / 10000 datasets.
# analyzed 70 / 10000 datasets.
# analyzed 80 / 10000 datasets.
# analyzed 90 / 10000 datasets.
# analyzed 100 / 10000 datasets.
# analyzed 110 / 10000 datasets.
# analyzed 120 / 10000 datasets.
# analyzed 130 / 10000 datasets.
# analyzed 140 / 10000 datasets.
# analyzed 150 / 10000 datasets.
# analyzed 160 / 10000 datasets.
# analyzed 170 / 10000 datasets.
# analyzed 180 / 10000 datasets.
# analyzed 190 / 10000 datasets.
# analyzed 200 / 10000 datasets.
# analyzed 210 / 10000 datasets.
# analyzed 220 / 10000 datasets.
# analyzed 230 / 10000 datasets.
# analyzed 240 / 10000 datasets.
# analyzed 250 / 10000 datasets.
# analyzed 260 / 10000 datasets.
# analyzed 270 / 10000 datasets.
# analyzed 280 / 10000 datasets.
# analyzed 290 / 10000 datasets.
# analyzed 300 / 10000 datasets.
# analyzed 310 / 10000 datasets.
# analyzed 320 / 10000 datasets.
# analyzed 330 / 10000 datasets.
# analyzed 340 / 10000 datasets.
# analyzed 350 / 10000 datasets.
# analyzed 360 / 10000 datasets.
# analyzed 370 / 10000 datasets.
# analyzed 380 / 10000 datasets.
# analyzed 390 / 10000 datasets.
# analyzed 400 / 10000 datasets.
# analyzed 410 / 10000 datasets.
# analyzed 420 / 10000 datasets.
# analyzed 430 / 10000 datasets.
# analyzed 440 / 10000 datasets.
# analyzed 450 / 10000 datasets.
# analyzed 460 / 10000 datasets.
# analyzed 470 / 10000 datasets.
# analyzed 480 / 10000 datasets.
# analyzed 490 / 10000 datasets.
# analyzed 500 / 10000 datasets.
# analyzed 510 / 10000 datasets.
# analyzed 520 / 10000 datasets.
# analyzed 530 / 10000 datasets.
# analyzed 540 / 10000 datasets.
# analyzed 550 / 10000 datasets.
# analyzed 560 / 10000 datasets.
# analyzed 570 / 10000 datasets.
# analyzed 580 / 10000 datasets.
# analyzed 590 / 10000 datasets.
# analyzed 600 / 10000 datasets.
# analyzed 610 / 10000 datasets.
# analyzed 620 / 10000 datasets.
# analyzed 630 / 10000 datasets.
# analyzed 640 / 10000 datasets.
# analyzed 650 / 10000 datasets.
# analyzed 660 / 10000 datasets.
# analyzed 670 / 10000 datasets.
# analyzed 680 / 10000 datasets.
# analyzed 690 / 10000 datasets.
# analyzed 700 / 10000 datasets.
# analyzed 710 / 10000 datasets.
# analyzed 720 / 10000 datasets.
# analyzed 730 / 10000 datasets.
# analyzed 740 / 10000 datasets.
# analyzed 750 / 10000 datasets.
# analyzed 760 / 10000 datasets.
# analyzed 770 / 10000 datasets.
# analyzed 780 / 10000 datasets.
# analyzed 790 / 10000 datasets.
# analyzed 800 / 10000 datasets.
# analyzed 810 / 10000 datasets.
# analyzed 820 / 10000 datasets.
# analyzed 830 / 10000 datasets.
# analyzed 840 / 10000 datasets.
# analyzed 850 / 10000 datasets.
# analyzed 860 / 10000 datasets.
# analyzed 870 / 10000 datasets.
# analyzed 880 / 10000 datasets.
# analyzed 890 / 10000 datasets.
# analyzed 900 / 10000 datasets.
# analyzed 910 / 10000 datasets.
# analyzed 920 / 10000 datasets.
# analyzed 930 / 10000 datasets.
# analyzed 940 / 10000 datasets.
# analyzed 950 / 10000 datasets.
# analyzed 960 / 10000 datasets.
# analyzed 970 / 10000 datasets.
# analyzed 980 / 10000 datasets.
# analyzed 990 / 10000 datasets.
# analyzed 1000 / 10000 datasets.
# analyzed 1010 / 10000 datasets.
# analyzed 1020 / 10000 datasets.
# analyzed 1030 / 10000 datasets.
# analyzed 1040 / 10000 datasets.
# analyzed 1050 / 10000 datasets.
# analyzed 1060 / 10000 datasets.
# analyzed 1070 / 10000 datasets.
# analyzed 1080 / 10000 datasets.
# analyzed 1090 / 10000 datasets.
# analyzed 1100 / 10000 datasets.
# analyzed 1110 / 10000 datasets.
# analyzed 1120 / 10000 datasets.
# analyzed 1130 / 10000 datasets.
# analyzed 1140 / 10000 datasets.
# analyzed 1150 / 10000 datasets.
# analyzed 1160 / 10000 datasets.
# analyzed 1170 / 10000 datasets.
# analyzed 1180 / 10000 datasets.
# analyzed 1190 / 10000 datasets.
# analyzed 1200 / 10000 datasets.
# analyzed 1210 / 10000 datasets.
# analyzed 1220 / 10000 datasets.
# analyzed 1230 / 10000 datasets.
# analyzed 1240 / 10000 datasets.
# analyzed 1250 / 10000 datasets.
# analyzed 1260 / 10000 datasets.
# analyzed 1270 / 10000 datasets.
# analyzed 1280 / 10000 datasets.
# analyzed 1290 / 10000 datasets.
# analyzed 1300 / 10000 datasets.
# analyzed 1310 / 10000 datasets.
# analyzed 1320 / 10000 datasets.
# analyzed 1330 / 10000 datasets.
# analyzed 1340 / 10000 datasets.
# analyzed 1350 / 10000 datasets.
# analyzed 1360 / 10000 datasets.
# analyzed 1370 / 10000 datasets.
# analyzed 1380 / 10000 datasets.
# analyzed 1390 / 10000 datasets.
# analyzed 1400 / 10000 datasets.
# analyzed 1410 / 10000 datasets.
# analyzed 1420 / 10000 datasets.
# analyzed 1430 / 10000 datasets.
# analyzed 1440 / 10000 datasets.
# analyzed 1450 / 10000 datasets.
# analyzed 1460 / 10000 datasets.
# analyzed 1470 / 10000 datasets.
# analyzed 1480 / 10000 datasets.
# analyzed 1490 / 10000 datasets.
# analyzed 1500 / 10000 datasets.
# analyzed 1510 / 10000 datasets.
# analyzed 1520 / 10000 datasets.
# analyzed 1530 / 10000 datasets.
# analyzed 1540 / 10000 datasets.
# analyzed 1550 / 10000 datasets.
# analyzed 1560 / 10000 datasets.
# analyzed 1570 / 10000 datasets.
# analyzed 1580 / 10000 datasets.
# analyzed 1590 / 10000 datasets.
# analyzed 1600 / 10000 datasets.
# analyzed 1610 / 10000 datasets.
# analyzed 1620 / 10000 datasets.
# analyzed 1630 / 10000 datasets.
# analyzed 1640 / 10000 datasets.
# analyzed 1650 / 10000 datasets.
# analyzed 1660 / 10000 datasets.
# analyzed 1670 / 10000 datasets.
# analyzed 1680 / 10000 datasets.
# analyzed 1690 / 10000 datasets.
# analyzed 1700 / 10000 datasets.
# analyzed 1710 / 10000 datasets.
# analyzed 1720 / 10000 datasets.
# analyzed 1730 / 10000 datasets.
# analyzed 1740 / 10000 datasets.
# analyzed 1750 / 10000 datasets.
# analyzed 1760 / 10000 datasets.
# analyzed 1770 / 10000 datasets.
# analyzed 1780 / 10000 datasets.
# analyzed 1790 / 10000 datasets.
# analyzed 1800 / 10000 datasets.
# analyzed 1810 / 10000 datasets.
# analyzed 1820 / 10000 datasets.
# analyzed 1830 / 10000 datasets.
# analyzed 1840 / 10000 datasets.
# analyzed 1850 / 10000 datasets.
# analyzed 1860 / 10000 datasets.
# analyzed 1870 / 10000 datasets.
# analyzed 1880 / 10000 datasets.
# analyzed 1890 / 10000 datasets.
# analyzed 1900 / 10000 datasets.
# analyzed 1910 / 10000 datasets.
# analyzed 1920 / 10000 datasets.
# analyzed 1930 / 10000 datasets.
# analyzed 1940 / 10000 datasets.
# analyzed 1950 / 10000 datasets.
# analyzed 1960 / 10000 datasets.
# analyzed 1970 / 10000 datasets.
# analyzed 1980 / 10000 datasets.
# analyzed 1990 / 10000 datasets.
# analyzed 2000 / 10000 datasets.
# analyzed 2010 / 10000 datasets.
# analyzed 2020 / 10000 datasets.
# analyzed 2030 / 10000 datasets.
# analyzed 2040 / 10000 datasets.
# analyzed 2050 / 10000 datasets.
# analyzed 2060 / 10000 datasets.
# analyzed 2070 / 10000 datasets.
# analyzed 2080 / 10000 datasets.
# analyzed 2090 / 10000 datasets.
# analyzed 2100 / 10000 datasets.
# analyzed 2110 / 10000 datasets.
# analyzed 2120 / 10000 datasets.
# analyzed 2130 / 10000 datasets.
# analyzed 2140 / 10000 datasets.
# analyzed 2150 / 10000 datasets.
# analyzed 2160 / 10000 datasets.
# analyzed 2170 / 10000 datasets.
# analyzed 2180 / 10000 datasets.
# analyzed 2190 / 10000 datasets.
# analyzed 2200 / 10000 datasets.
# analyzed 2210 / 10000 datasets.
# analyzed 2220 / 10000 datasets.
# analyzed 2230 / 10000 datasets.
# analyzed 2240 / 10000 datasets.
# analyzed 2250 / 10000 datasets.
# analyzed 2260 / 10000 datasets.
# analyzed 2270 / 10000 datasets.
# analyzed 2280 / 10000 datasets.
# analyzed 2290 / 10000 datasets.
# analyzed 2300 / 10000 datasets.
# analyzed 2310 / 10000 datasets.
# analyzed 2320 / 10000 datasets.
# analyzed 2330 / 10000 datasets.
# analyzed 2340 / 10000 datasets.
# analyzed 2350 / 10000 datasets.
# analyzed 2360 / 10000 datasets.
# analyzed 2370 / 10000 datasets.
# analyzed 2380 / 10000 datasets.
# analyzed 2390 / 10000 datasets.
# analyzed 2400 / 10000 datasets.
# analyzed 2410 / 10000 datasets.
# analyzed 2420 / 10000 datasets.
# analyzed 2430 / 10000 datasets.
# analyzed 2440 / 10000 datasets.
# analyzed 2450 / 10000 datasets.
# analyzed 2460 / 10000 datasets.
# analyzed 2470 / 10000 datasets.
# analyzed 2480 / 10000 datasets.
# analyzed 2490 / 10000 datasets.
# analyzed 2500 / 10000 datasets.
# analyzed 2510 / 10000 datasets.
# analyzed 2520 / 10000 datasets.
# analyzed 2530 / 10000 datasets.
# analyzed 2540 / 10000 datasets.
# analyzed 2550 / 10000 datasets.
# analyzed 2560 / 10000 datasets.
# analyzed 2570 / 10000 datasets.
# analyzed 2580 / 10000 datasets.
# analyzed 2590 / 10000 datasets.
# analyzed 2600 / 10000 datasets.
# analyzed 2610 / 10000 datasets.
# analyzed 2620 / 10000 datasets.
# analyzed 2630 / 10000 datasets.
# analyzed 2640 / 10000 datasets.
# analyzed 2650 / 10000 datasets.
# analyzed 2660 / 10000 datasets.
# analyzed 2670 / 10000 datasets.
# analyzed 2680 / 10000 datasets.
# analyzed 2690 / 10000 datasets.
# analyzed 2700 / 10000 datasets.
# analyzed 2710 / 10000 datasets.
# analyzed 2720 / 10000 datasets.
# analyzed 2730 / 10000 datasets.
# analyzed 2740 / 10000 datasets.
# analyzed 2750 / 10000 datasets.
# analyzed 2760 / 10000 datasets.
# analyzed 2770 / 10000 datasets.
# analyzed 2780 / 10000 datasets.
# analyzed 2790 / 10000 datasets.
# analyzed 2800 / 10000 datasets.
# analyzed 2810 / 10000 datasets.
# analyzed 2820 / 10000 datasets.
# analyzed 2830 / 10000 datasets.
# analyzed 2840 / 10000 datasets.
# analyzed 2850 / 10000 datasets.
# analyzed 2860 / 10000 datasets.
# analyzed 2870 / 10000 datasets.
# analyzed 2880 / 10000 datasets.
# analyzed 2890 / 10000 datasets.
# analyzed 2900 / 10000 datasets.
# analyzed 2910 / 10000 datasets.
# analyzed 2920 / 10000 datasets.
# analyzed 2930 / 10000 datasets.
# analyzed 2940 / 10000 datasets.
# analyzed 2950 / 10000 datasets.
# analyzed 2960 / 10000 datasets.
# analyzed 2970 / 10000 datasets.
# analyzed 2980 / 10000 datasets.
# analyzed 2990 / 10000 datasets.
# analyzed 3000 / 10000 datasets.
# analyzed 3010 / 10000 datasets.
# analyzed 3020 / 10000 datasets.
# analyzed 3030 / 10000 datasets.
# analyzed 3040 / 10000 datasets.
# analyzed 3050 / 10000 datasets.
# analyzed 3060 / 10000 datasets.
# analyzed 3070 / 10000 datasets.
# analyzed 3080 / 10000 datasets.
# analyzed 3090 / 10000 datasets.
# analyzed 3100 / 10000 datasets.
# analyzed 3110 / 10000 datasets.
# analyzed 3120 / 10000 datasets.
# analyzed 3130 / 10000 datasets.
# analyzed 3140 / 10000 datasets.
# analyzed 3150 / 10000 datasets.
# analyzed 3160 / 10000 datasets.
# analyzed 3170 / 10000 datasets.
# analyzed 3180 / 10000 datasets.
# analyzed 3190 / 10000 datasets.
# analyzed 3200 / 10000 datasets.
# analyzed 3210 / 10000 datasets.
# analyzed 3220 / 10000 datasets.
# analyzed 3230 / 10000 datasets.
# analyzed 3240 / 10000 datasets.
# analyzed 3250 / 10000 datasets.
# analyzed 3260 / 10000 datasets.
# analyzed 3270 / 10000 datasets.
# analyzed 3280 / 10000 datasets.
# analyzed 3290 / 10000 datasets.
# analyzed 3300 / 10000 datasets.
# analyzed 3310 / 10000 datasets.
# analyzed 3320 / 10000 datasets.
# analyzed 3330 / 10000 datasets.
# analyzed 3340 / 10000 datasets.
# analyzed 3350 / 10000 datasets.
# analyzed 3360 / 10000 datasets.
# analyzed 3370 / 10000 datasets.
# analyzed 3380 / 10000 datasets.
# analyzed 3390 / 10000 datasets.
# analyzed 3400 / 10000 datasets.
# analyzed 3410 / 10000 datasets.
# analyzed 3420 / 10000 datasets.
# analyzed 3430 / 10000 datasets.
# analyzed 3440 / 10000 datasets.
# analyzed 3450 / 10000 datasets.
# analyzed 3460 / 10000 datasets.
# analyzed 3470 / 10000 datasets.
# analyzed 3480 / 10000 datasets.
# analyzed 3490 / 10000 datasets.
# analyzed 3500 / 10000 datasets.
# analyzed 3510 / 10000 datasets.
# analyzed 3520 / 10000 datasets.
# analyzed 3530 / 10000 datasets.
# analyzed 3540 / 10000 datasets.
# analyzed 3550 / 10000 datasets.
# analyzed 3560 / 10000 datasets.
# analyzed 3570 / 10000 datasets.
# analyzed 3580 / 10000 datasets.
# analyzed 3590 / 10000 datasets.
# analyzed 3600 / 10000 datasets.
# analyzed 3610 / 10000 datasets.
# analyzed 3620 / 10000 datasets.
# analyzed 3630 / 10000 datasets.
# analyzed 3640 / 10000 datasets.
# analyzed 3650 / 10000 datasets.
# analyzed 3660 / 10000 datasets.
# analyzed 3670 / 10000 datasets.
# analyzed 3680 / 10000 datasets.
# analyzed 3690 / 10000 datasets.
# analyzed 3700 / 10000 datasets.
# analyzed 3710 / 10000 datasets.
# analyzed 3720 / 10000 datasets.
# analyzed 3730 / 10000 datasets.
# analyzed 3740 / 10000 datasets.
# analyzed 3750 / 10000 datasets.
# analyzed 3760 / 10000 datasets.
# analyzed 3770 / 10000 datasets.
# analyzed 3780 / 10000 datasets.
# analyzed 3790 / 10000 datasets.
# analyzed 3800 / 10000 datasets.
# analyzed 3810 / 10000 datasets.
# analyzed 3820 / 10000 datasets.
# analyzed 3830 / 10000 datasets.
# analyzed 3840 / 10000 datasets.
# analyzed 3850 / 10000 datasets.
# analyzed 3860 / 10000 datasets.
# analyzed 3870 / 10000 datasets.
# analyzed 3880 / 10000 datasets.
# analyzed 3890 / 10000 datasets.
# analyzed 3900 / 10000 datasets.
# analyzed 3910 / 10000 datasets.
# analyzed 3920 / 10000 datasets.
# analyzed 3930 / 10000 datasets.
# analyzed 3940 / 10000 datasets.
# analyzed 3950 / 10000 datasets.
# analyzed 3960 / 10000 datasets.
# analyzed 3970 / 10000 datasets.
# analyzed 3980 / 10000 datasets.
# analyzed 3990 / 10000 datasets.
# analyzed 4000 / 10000 datasets.
# analyzed 4010 / 10000 datasets.
# analyzed 4020 / 10000 datasets.
# analyzed 4030 / 10000 datasets.
# analyzed 4040 / 10000 datasets.
# analyzed 4050 / 10000 datasets.
# analyzed 4060 / 10000 datasets.
# analyzed 4070 / 10000 datasets.
# analyzed 4080 / 10000 datasets.
# analyzed 4090 / 10000 datasets.
# analyzed 4100 / 10000 datasets.
# analyzed 4110 / 10000 datasets.
# analyzed 4120 / 10000 datasets.
# analyzed 4130 / 10000 datasets.
# analyzed 4140 / 10000 datasets.
# analyzed 4150 / 10000 datasets.
# analyzed 4160 / 10000 datasets.
# analyzed 4170 / 10000 datasets.
# analyzed 4180 / 10000 datasets.
# analyzed 4190 / 10000 datasets.
# analyzed 4200 / 10000 datasets.
# analyzed 4210 / 10000 datasets.
# analyzed 4220 / 10000 datasets.
# analyzed 4230 / 10000 datasets.
# analyzed 4240 / 10000 datasets.
# analyzed 4250 / 10000 datasets.
# analyzed 4260 / 10000 datasets.
# analyzed 4270 / 10000 datasets.
# analyzed 4280 / 10000 datasets.
# analyzed 4290 / 10000 datasets.
# analyzed 4300 / 10000 datasets.
# analyzed 4310 / 10000 datasets.
# analyzed 4320 / 10000 datasets.
# analyzed 4330 / 10000 datasets.
# analyzed 4340 / 10000 datasets.
# analyzed 4350 / 10000 datasets.
# analyzed 4360 / 10000 datasets.
# analyzed 4370 / 10000 datasets.
# analyzed 4380 / 10000 datasets.
# analyzed 4390 / 10000 datasets.
# analyzed 4400 / 10000 datasets.
# analyzed 4410 / 10000 datasets.
# analyzed 4420 / 10000 datasets.
# analyzed 4430 / 10000 datasets.
# analyzed 4440 / 10000 datasets.
# analyzed 4450 / 10000 datasets.
# analyzed 4460 / 10000 datasets.
# analyzed 4470 / 10000 datasets.
# analyzed 4480 / 10000 datasets.
# analyzed 4490 / 10000 datasets.
# analyzed 4500 / 10000 datasets.
# analyzed 4510 / 10000 datasets.
# analyzed 4520 / 10000 datasets.
# analyzed 4530 / 10000 datasets.
# analyzed 4540 / 10000 datasets.
# analyzed 4550 / 10000 datasets.
# analyzed 4560 / 10000 datasets.
# analyzed 4570 / 10000 datasets.
# analyzed 4580 / 10000 datasets.
# analyzed 4590 / 10000 datasets.
# analyzed 4600 / 10000 datasets.
# analyzed 4610 / 10000 datasets.
# analyzed 4620 / 10000 datasets.
# analyzed 4630 / 10000 datasets.
# analyzed 4640 / 10000 datasets.
# analyzed 4650 / 10000 datasets.
# analyzed 4660 / 10000 datasets.
# analyzed 4670 / 10000 datasets.
# analyzed 4680 / 10000 datasets.
# analyzed 4690 / 10000 datasets.
# analyzed 4700 / 10000 datasets.
# analyzed 4710 / 10000 datasets.
# analyzed 4720 / 10000 datasets.
# analyzed 4730 / 10000 datasets.
# analyzed 4740 / 10000 datasets.
# analyzed 4750 / 10000 datasets.
# analyzed 4760 / 10000 datasets.
# analyzed 4770 / 10000 datasets.
# analyzed 4780 / 10000 datasets.
# analyzed 4790 / 10000 datasets.
# analyzed 4800 / 10000 datasets.
# analyzed 4810 / 10000 datasets.
# analyzed 4820 / 10000 datasets.
# analyzed 4830 / 10000 datasets.
# analyzed 4840 / 10000 datasets.
# analyzed 4850 / 10000 datasets.
# analyzed 4860 / 10000 datasets.
# analyzed 4870 / 10000 datasets.
# analyzed 4880 / 10000 datasets.
# analyzed 4890 / 10000 datasets.
# analyzed 4900 / 10000 datasets.
# analyzed 4910 / 10000 datasets.
# analyzed 4920 / 10000 datasets.
# analyzed 4930 / 10000 datasets.
# analyzed 4940 / 10000 datasets.
# analyzed 4950 / 10000 datasets.
# analyzed 4960 / 10000 datasets.
# analyzed 4970 / 10000 datasets.
# analyzed 4980 / 10000 datasets.
# analyzed 4990 / 10000 datasets.
# analyzed 5000 / 10000 datasets.
# analyzed 5010 / 10000 datasets.
# analyzed 5020 / 10000 datasets.
# analyzed 5030 / 10000 datasets.
# analyzed 5040 / 10000 datasets.
# analyzed 5050 / 10000 datasets.
# analyzed 5060 / 10000 datasets.
# analyzed 5070 / 10000 datasets.
# analyzed 5080 / 10000 datasets.
# analyzed 5090 / 10000 datasets.
# analyzed 5100 / 10000 datasets.
# analyzed 5110 / 10000 datasets.
# analyzed 5120 / 10000 datasets.
# analyzed 5130 / 10000 datasets.
# analyzed 5140 / 10000 datasets.
# analyzed 5150 / 10000 datasets.
# analyzed 5160 / 10000 datasets.
# analyzed 5170 / 10000 datasets.
# analyzed 5180 / 10000 datasets.
# analyzed 5190 / 10000 datasets.
# analyzed 5200 / 10000 datasets.
# analyzed 5210 / 10000 datasets.
# analyzed 5220 / 10000 datasets.
# analyzed 5230 / 10000 datasets.
# analyzed 5240 / 10000 datasets.
# analyzed 5250 / 10000 datasets.
# analyzed 5260 / 10000 datasets.
# analyzed 5270 / 10000 datasets.
# analyzed 5280 / 10000 datasets.
# analyzed 5290 / 10000 datasets.
# analyzed 5300 / 10000 datasets.
# analyzed 5310 / 10000 datasets.
# analyzed 5320 / 10000 datasets.
# analyzed 5330 / 10000 datasets.
# analyzed 5340 / 10000 datasets.
# analyzed 5350 / 10000 datasets.
# analyzed 5360 / 10000 datasets.
# analyzed 5370 / 10000 datasets.
# analyzed 5380 / 10000 datasets.
# analyzed 5390 / 10000 datasets.
# analyzed 5400 / 10000 datasets.
# analyzed 5410 / 10000 datasets.
# analyzed 5420 / 10000 datasets.
# analyzed 5430 / 10000 datasets.
# analyzed 5440 / 10000 datasets.
# analyzed 5450 / 10000 datasets.
# analyzed 5460 / 10000 datasets.
# analyzed 5470 / 10000 datasets.
# analyzed 5480 / 10000 datasets.
# analyzed 5490 / 10000 datasets.
# analyzed 5500 / 10000 datasets.
# analyzed 5510 / 10000 datasets.
# analyzed 5520 / 10000 datasets.
# analyzed 5530 / 10000 datasets.
# analyzed 5540 / 10000 datasets.
# analyzed 5550 / 10000 datasets.
# analyzed 5560 / 10000 datasets.
# analyzed 5570 / 10000 datasets.
# analyzed 5580 / 10000 datasets.
# analyzed 5590 / 10000 datasets.
# analyzed 5600 / 10000 datasets.
# analyzed 5610 / 10000 datasets.
# analyzed 5620 / 10000 datasets.
# analyzed 5630 / 10000 datasets.
# analyzed 5640 / 10000 datasets.
# analyzed 5650 / 10000 datasets.
# analyzed 5660 / 10000 datasets.
# analyzed 5670 / 10000 datasets.
# analyzed 5680 / 10000 datasets.
# analyzed 5690 / 10000 datasets.
# analyzed 5700 / 10000 datasets.
# analyzed 5710 / 10000 datasets.
# analyzed 5720 / 10000 datasets.
# analyzed 5730 / 10000 datasets.
# analyzed 5740 / 10000 datasets.
# analyzed 5750 / 10000 datasets.
# analyzed 5760 / 10000 datasets.
# analyzed 5770 / 10000 datasets.
# analyzed 5780 / 10000 datasets.
# analyzed 5790 / 10000 datasets.
# analyzed 5800 / 10000 datasets.
# analyzed 5810 / 10000 datasets.
# analyzed 5820 / 10000 datasets.
# analyzed 5830 / 10000 datasets.
# analyzed 5840 / 10000 datasets.
# analyzed 5850 / 10000 datasets.
# analyzed 5860 / 10000 datasets.
# analyzed 5870 / 10000 datasets.
# analyzed 5880 / 10000 datasets.
# analyzed 5890 / 10000 datasets.
# analyzed 5900 / 10000 datasets.
# analyzed 5910 / 10000 datasets.
# analyzed 5920 / 10000 datasets.
# analyzed 5930 / 10000 datasets.
# analyzed 5940 / 10000 datasets.
# analyzed 5950 / 10000 datasets.
# analyzed 5960 / 10000 datasets.
# analyzed 5970 / 10000 datasets.
# analyzed 5980 / 10000 datasets.
# analyzed 5990 / 10000 datasets.
# analyzed 6000 / 10000 datasets.
# analyzed 6010 / 10000 datasets.
# analyzed 6020 / 10000 datasets.
# analyzed 6030 / 10000 datasets.
# analyzed 6040 / 10000 datasets.
# analyzed 6050 / 10000 datasets.
# analyzed 6060 / 10000 datasets.
# analyzed 6070 / 10000 datasets.
# analyzed 6080 / 10000 datasets.
# analyzed 6090 / 10000 datasets.
# analyzed 6100 / 10000 datasets.
# analyzed 6110 / 10000 datasets.
# analyzed 6120 / 10000 datasets.
# analyzed 6130 / 10000 datasets.
# analyzed 6140 / 10000 datasets.
# analyzed 6150 / 10000 datasets.
# analyzed 6160 / 10000 datasets.
# analyzed 6170 / 10000 datasets.
# analyzed 6180 / 10000 datasets.
# analyzed 6190 / 10000 datasets.
# analyzed 6200 / 10000 datasets.
# analyzed 6210 / 10000 datasets.
# analyzed 6220 / 10000 datasets.
# analyzed 6230 / 10000 datasets.
# analyzed 6240 / 10000 datasets.
# analyzed 6250 / 10000 datasets.
# analyzed 6260 / 10000 datasets.
# analyzed 6270 / 10000 datasets.
# analyzed 6280 / 10000 datasets.
# analyzed 6290 / 10000 datasets.
# analyzed 6300 / 10000 datasets.
# analyzed 6310 / 10000 datasets.
# analyzed 6320 / 10000 datasets.
# analyzed 6330 / 10000 datasets.
# analyzed 6340 / 10000 datasets.
# analyzed 6350 / 10000 datasets.
# analyzed 6360 / 10000 datasets.
# analyzed 6370 / 10000 datasets.
# analyzed 6380 / 10000 datasets.
# analyzed 6390 / 10000 datasets.
# analyzed 6400 / 10000 datasets.
# analyzed 6410 / 10000 datasets.
# analyzed 6420 / 10000 datasets.
# analyzed 6430 / 10000 datasets.
# analyzed 6440 / 10000 datasets.
# analyzed 6450 / 10000 datasets.
# analyzed 6460 / 10000 datasets.
# analyzed 6470 / 10000 datasets.
# analyzed 6480 / 10000 datasets.
# analyzed 6490 / 10000 datasets.
# analyzed 6500 / 10000 datasets.
# analyzed 6510 / 10000 datasets.
# analyzed 6520 / 10000 datasets.
# analyzed 6530 / 10000 datasets.
# analyzed 6540 / 10000 datasets.
# analyzed 6550 / 10000 datasets.
# analyzed 6560 / 10000 datasets.
# analyzed 6570 / 10000 datasets.
# analyzed 6580 / 10000 datasets.
# analyzed 6590 / 10000 datasets.
# analyzed 6600 / 10000 datasets.
# analyzed 6610 / 10000 datasets.
# analyzed 6620 / 10000 datasets.
# analyzed 6630 / 10000 datasets.
# analyzed 6640 / 10000 datasets.
# analyzed 6650 / 10000 datasets.
# analyzed 6660 / 10000 datasets.
# analyzed 6670 / 10000 datasets.
# analyzed 6680 / 10000 datasets.
# analyzed 6690 / 10000 datasets.
# analyzed 6700 / 10000 datasets.
# analyzed 6710 / 10000 datasets.
# analyzed 6720 / 10000 datasets.
# analyzed 6730 / 10000 datasets.
# analyzed 6740 / 10000 datasets.
# analyzed 6750 / 10000 datasets.
# analyzed 6760 / 10000 datasets.
# analyzed 6770 / 10000 datasets.
# analyzed 6780 / 10000 datasets.
# analyzed 6790 / 10000 datasets.
# analyzed 6800 / 10000 datasets.
# analyzed 6810 / 10000 datasets.
# analyzed 6820 / 10000 datasets.
# analyzed 6830 / 10000 datasets.
# analyzed 6840 / 10000 datasets.
# analyzed 6850 / 10000 datasets.
# analyzed 6860 / 10000 datasets.
# analyzed 6870 / 10000 datasets.
# analyzed 6880 / 10000 datasets.
# analyzed 6890 / 10000 datasets.
# analyzed 6900 / 10000 datasets.
# analyzed 6910 / 10000 datasets.
# analyzed 6920 / 10000 datasets.
# analyzed 6930 / 10000 datasets.
# analyzed 6940 / 10000 datasets.
# analyzed 6950 / 10000 datasets.
# analyzed 6960 / 10000 datasets.
# analyzed 6970 / 10000 datasets.
# analyzed 6980 / 10000 datasets.
# analyzed 6990 / 10000 datasets.
# analyzed 7000 / 10000 datasets.
# analyzed 7010 / 10000 datasets.
# analyzed 7020 / 10000 datasets.
# analyzed 7030 / 10000 datasets.
# analyzed 7040 / 10000 datasets.
# analyzed 7050 / 10000 datasets.
# analyzed 7060 / 10000 datasets.
# analyzed 7070 / 10000 datasets.
# analyzed 7080 / 10000 datasets.
# analyzed 7090 / 10000 datasets.
# analyzed 7100 / 10000 datasets.
# analyzed 7110 / 10000 datasets.
# analyzed 7120 / 10000 datasets.
# analyzed 7130 / 10000 datasets.
# analyzed 7140 / 10000 datasets.
# analyzed 7150 / 10000 datasets.
# analyzed 7160 / 10000 datasets.
# analyzed 7170 / 10000 datasets.
# analyzed 7180 / 10000 datasets.
# analyzed 7190 / 10000 datasets.
# analyzed 7200 / 10000 datasets.
# analyzed 7210 / 10000 datasets.
# analyzed 7220 / 10000 datasets.
# analyzed 7230 / 10000 datasets.
# analyzed 7240 / 10000 datasets.
# analyzed 7250 / 10000 datasets.
# analyzed 7260 / 10000 datasets.
# analyzed 7270 / 10000 datasets.
# analyzed 7280 / 10000 datasets.
# analyzed 7290 / 10000 datasets.
# analyzed 7300 / 10000 datasets.
# analyzed 7310 / 10000 datasets.
# analyzed 7320 / 10000 datasets.
# analyzed 7330 / 10000 datasets.
# analyzed 7340 / 10000 datasets.
# analyzed 7350 / 10000 datasets.
# analyzed 7360 / 10000 datasets.
# analyzed 7370 / 10000 datasets.
# analyzed 7380 / 10000 datasets.
# analyzed 7390 / 10000 datasets.
# analyzed 7400 / 10000 datasets.
# analyzed 7410 / 10000 datasets.
# analyzed 7420 / 10000 datasets.
# analyzed 7430 / 10000 datasets.
# analyzed 7440 / 10000 datasets.
# analyzed 7450 / 10000 datasets.
# analyzed 7460 / 10000 datasets.
# analyzed 7470 / 10000 datasets.
# analyzed 7480 / 10000 datasets.
# analyzed 7490 / 10000 datasets.
# analyzed 7500 / 10000 datasets.
# analyzed 7510 / 10000 datasets.
# analyzed 7520 / 10000 datasets.
# analyzed 7530 / 10000 datasets.
# analyzed 7540 / 10000 datasets.
# analyzed 7550 / 10000 datasets.
# analyzed 7560 / 10000 datasets.
# analyzed 7570 / 10000 datasets.
# analyzed 7580 / 10000 datasets.
# analyzed 7590 / 10000 datasets.
# analyzed 7600 / 10000 datasets.
# analyzed 7610 / 10000 datasets.
# analyzed 7620 / 10000 datasets.
# analyzed 7630 / 10000 datasets.
# analyzed 7640 / 10000 datasets.
# analyzed 7650 / 10000 datasets.
# analyzed 7660 / 10000 datasets.
# analyzed 7670 / 10000 datasets.
# analyzed 7680 / 10000 datasets.
# analyzed 7690 / 10000 datasets.
# analyzed 7700 / 10000 datasets.
# analyzed 7710 / 10000 datasets.
# analyzed 7720 / 10000 datasets.
# analyzed 7730 / 10000 datasets.
# analyzed 7740 / 10000 datasets.
# analyzed 7750 / 10000 datasets.
# analyzed 7760 / 10000 datasets.
# analyzed 7770 / 10000 datasets.
# analyzed 7780 / 10000 datasets.
# analyzed 7790 / 10000 datasets.
# analyzed 7800 / 10000 datasets.
# analyzed 7810 / 10000 datasets.
# analyzed 7820 / 10000 datasets.
# analyzed 7830 / 10000 datasets.
# analyzed 7840 / 10000 datasets.
# analyzed 7850 / 10000 datasets.
# analyzed 7860 / 10000 datasets.
# analyzed 7870 / 10000 datasets.
# analyzed 7880 / 10000 datasets.
# analyzed 7890 / 10000 datasets.
# analyzed 7900 / 10000 datasets.
# analyzed 7910 / 10000 datasets.
# analyzed 7920 / 10000 datasets.
# analyzed 7930 / 10000 datasets.
# analyzed 7940 / 10000 datasets.
# analyzed 7950 / 10000 datasets.
# analyzed 7960 / 10000 datasets.
# analyzed 7970 / 10000 datasets.
# analyzed 7980 / 10000 datasets.
# analyzed 7990 / 10000 datasets.
# analyzed 8000 / 10000 datasets.
# analyzed 8010 / 10000 datasets.
# analyzed 8020 / 10000 datasets.
# analyzed 8030 / 10000 datasets.
# analyzed 8040 / 10000 datasets.
# analyzed 8050 / 10000 datasets.
# analyzed 8060 / 10000 datasets.
# analyzed 8070 / 10000 datasets.
# analyzed 8080 / 10000 datasets.
# analyzed 8090 / 10000 datasets.
# analyzed 8100 / 10000 datasets.
# analyzed 8110 / 10000 datasets.
# analyzed 8120 / 10000 datasets.
# analyzed 8130 / 10000 datasets.
# analyzed 8140 / 10000 datasets.
# analyzed 8150 / 10000 datasets.
# analyzed 8160 / 10000 datasets.
# analyzed 8170 / 10000 datasets.
# analyzed 8180 / 10000 datasets.
# analyzed 8190 / 10000 datasets.
# analyzed 8200 / 10000 datasets.
# analyzed 8210 / 10000 datasets.
# analyzed 8220 / 10000 datasets.
# analyzed 8230 / 10000 datasets.
# analyzed 8240 / 10000 datasets.
# analyzed 8250 / 10000 datasets.
# analyzed 8260 / 10000 datasets.
# analyzed 8270 / 10000 datasets.
# analyzed 8280 / 10000 datasets.
# analyzed 8290 / 10000 datasets.
# analyzed 8300 / 10000 datasets.
# analyzed 8310 / 10000 datasets.
# analyzed 8320 / 10000 datasets.
# analyzed 8330 / 10000 datasets.
# analyzed 8340 / 10000 datasets.
# analyzed 8350 / 10000 datasets.
# analyzed 8360 / 10000 datasets.
# analyzed 8370 / 10000 datasets.
# analyzed 8380 / 10000 datasets.
# analyzed 8390 / 10000 datasets.
# analyzed 8400 / 10000 datasets.
# analyzed 8410 / 10000 datasets.
# analyzed 8420 / 10000 datasets.
# analyzed 8430 / 10000 datasets.
# analyzed 8440 / 10000 datasets.
# analyzed 8450 / 10000 datasets.
# analyzed 8460 / 10000 datasets.
# analyzed 8470 / 10000 datasets.
# analyzed 8480 / 10000 datasets.
# analyzed 8490 / 10000 datasets.
# analyzed 8500 / 10000 datasets.
# analyzed 8510 / 10000 datasets.
# analyzed 8520 / 10000 datasets.
# analyzed 8530 / 10000 datasets.
# analyzed 8540 / 10000 datasets.
# analyzed 8550 / 10000 datasets.
# analyzed 8560 / 10000 datasets.
# analyzed 8570 / 10000 datasets.
# analyzed 8580 / 10000 datasets.
# analyzed 8590 / 10000 datasets.
# analyzed 8600 / 10000 datasets.
# analyzed 8610 / 10000 datasets.
# analyzed 8620 / 10000 datasets.
# analyzed 8630 / 10000 datasets.
# analyzed 8640 / 10000 datasets.
# analyzed 8650 / 10000 datasets.
# analyzed 8660 / 10000 datasets.
# analyzed 8670 / 10000 datasets.
# analyzed 8680 / 10000 datasets.
# analyzed 8690 / 10000 datasets.
# analyzed 8700 / 10000 datasets.
# analyzed 8710 / 10000 datasets.
# analyzed 8720 / 10000 datasets.
# analyzed 8730 / 10000 datasets.
# analyzed 8740 / 10000 datasets.
# analyzed 8750 / 10000 datasets.
# analyzed 8760 / 10000 datasets.
# analyzed 8770 / 10000 datasets.
# analyzed 8780 / 10000 datasets.
# analyzed 8790 / 10000 datasets.
# analyzed 8800 / 10000 datasets.
# analyzed 8810 / 10000 datasets.
# analyzed 8820 / 10000 datasets.
# analyzed 8830 / 10000 datasets.
# analyzed 8840 / 10000 datasets.
# analyzed 8850 / 10000 datasets.
# analyzed 8860 / 10000 datasets.
# analyzed 8870 / 10000 datasets.
# analyzed 8880 / 10000 datasets.
# analyzed 8890 / 10000 datasets.
# analyzed 8900 / 10000 datasets.
# analyzed 8910 / 10000 datasets.
# analyzed 8920 / 10000 datasets.
# analyzed 8930 / 10000 datasets.
# analyzed 8940 / 10000 datasets.
# analyzed 8950 / 10000 datasets.
# analyzed 8960 / 10000 datasets.
# analyzed 8970 / 10000 datasets.
# analyzed 8980 / 10000 datasets.
# analyzed 8990 / 10000 datasets.
# analyzed 9000 / 10000 datasets.
# analyzed 9010 / 10000 datasets.
# analyzed 9020 / 10000 datasets.
# analyzed 9030 / 10000 datasets.
# analyzed 9040 / 10000 datasets.
# analyzed 9050 / 10000 datasets.
# analyzed 9060 / 10000 datasets.
# analyzed 9070 / 10000 datasets.
# analyzed 9080 / 10000 datasets.
# analyzed 9090 / 10000 datasets.
# analyzed 9100 / 10000 datasets.
# analyzed 9110 / 10000 datasets.
# analyzed 9120 / 10000 datasets.
# analyzed 9130 / 10000 datasets.
# analyzed 9140 / 10000 datasets.
# analyzed 9150 / 10000 datasets.
# analyzed 9160 / 10000 datasets.
# analyzed 9170 / 10000 datasets.
# analyzed 9180 / 10000 datasets.
# analyzed 9190 / 10000 datasets.
# analyzed 9200 / 10000 datasets.
# analyzed 9210 / 10000 datasets.
# analyzed 9220 / 10000 datasets.
# analyzed 9230 / 10000 datasets.
# analyzed 9240 / 10000 datasets.
# analyzed 9250 / 10000 datasets.
# analyzed 9260 / 10000 datasets.
# analyzed 9270 / 10000 datasets.
# analyzed 9280 / 10000 datasets.
# analyzed 9290 / 10000 datasets.
# analyzed 9300 / 10000 datasets.
# analyzed 9310 / 10000 datasets.
# analyzed 9320 / 10000 datasets.
# analyzed 9330 / 10000 datasets.
# analyzed 9340 / 10000 datasets.
# analyzed 9350 / 10000 datasets.
# analyzed 9360 / 10000 datasets.
# analyzed 9370 / 10000 datasets.
# analyzed 9380 / 10000 datasets.
# analyzed 9390 / 10000 datasets.
# analyzed 9400 / 10000 datasets.
# analyzed 9410 / 10000 datasets.
# analyzed 9420 / 10000 datasets.
# analyzed 9430 / 10000 datasets.
# analyzed 9440 / 10000 datasets.
# analyzed 9450 / 10000 datasets.
# analyzed 9460 / 10000 datasets.
# analyzed 9470 / 10000 datasets.
# analyzed 9480 / 10000 datasets.
# analyzed 9490 / 10000 datasets.
# analyzed 9500 / 10000 datasets.
# analyzed 9510 / 10000 datasets.
# analyzed 9520 / 10000 datasets.
# analyzed 9530 / 10000 datasets.
# analyzed 9540 / 10000 datasets.
# analyzed 9550 / 10000 datasets.
# analyzed 9560 / 10000 datasets.
# analyzed 9570 / 10000 datasets.
# analyzed 9580 / 10000 datasets.
# analyzed 9590 / 10000 datasets.
# analyzed 9600 / 10000 datasets.
# analyzed 9610 / 10000 datasets.
# analyzed 9620 / 10000 datasets.
# analyzed 9630 / 10000 datasets.
# analyzed 9640 / 10000 datasets.
# analyzed 9650 / 10000 datasets.
# analyzed 9660 / 10000 datasets.
# analyzed 9670 / 10000 datasets.
# analyzed 9680 / 10000 datasets.
# analyzed 9690 / 10000 datasets.
# analyzed 9700 / 10000 datasets.
# analyzed 9710 / 10000 datasets.
# analyzed 9720 / 10000 datasets.
# analyzed 9730 / 10000 datasets.
# analyzed 9740 / 10000 datasets.
# analyzed 9750 / 10000 datasets.
# analyzed 9760 / 10000 datasets.
# analyzed 9770 / 10000 datasets.
# analyzed 9780 / 10000 datasets.
# analyzed 9790 / 10000 datasets.
# analyzed 9800 / 10000 datasets.
# analyzed 9810 / 10000 datasets.
# analyzed 9820 / 10000 datasets.
# analyzed 9830 / 10000 datasets.
# analyzed 9840 / 10000 datasets.
# analyzed 9850 / 10000 datasets.
# analyzed 9860 / 10000 datasets.
# analyzed 9870 / 10000 datasets.
# analyzed 9880 / 10000 datasets.
# analyzed 9890 / 10000 datasets.
# analyzed 9900 / 10000 datasets.
# analyzed 9910 / 10000 datasets.
# analyzed 9920 / 10000 datasets.
# analyzed 9930 / 10000 datasets.
# analyzed 9940 / 10000 datasets.
# analyzed 9950 / 10000 datasets.
# analyzed 9960 / 10000 datasets.
# analyzed 9970 / 10000 datasets.
# analyzed 9980 / 10000 datasets.
# analyzed 9990 / 10000 datasets.

# %%
import cPickle as pickle
with open('signal_trials_clregionTS.pickle', 'wb') as f:
    pickle.dump(results_pseudo_data_H1, f, protocol=pickle.HIGHEST_PROTOCOL)

fig, ax = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
plt.hist(results_pseudo_data_H1[2],bins=50, normed=True, label="signal injected")

ax.set_yscale('log')
ax.set_ylim([1.e-4, 2])
ax.set_xlabel('test-statistic', fontsize=20)
ax.set_ylabel('pdf', fontsize=20)
for axis in ['top','bottom','left','right']: 
    ax.spines[axis].set_linewidth(1.5)
    ax.spines[axis].set_color('0.0')

ax.tick_params(axis='both', which='both', width=1.5, colors='0.0', labelsize=20)
ax.yaxis.set_ticks_position('both')
ax.set_xlim([0.0, 25])

plt.legend(bbox_to_anchor=[0.99, 0.99], loc='upper right', prop={'size':13}, ncol=1, fancybox=True)

plt.show()
